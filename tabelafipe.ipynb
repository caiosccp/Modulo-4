# %%
import requests

# Instanciando a URL e o User-Agent
url_marcas = "https://parallelum.com.br/fipe/api/v1/carros/marcas"
headers = {
    "User-Agent": "MyApp/1.0"
}

# Obtendo informações da API através do método GET
response = requests.get(url_marcas, headers=headers)

# Salvando a resposta da API
marcas = response.json()

# %%
# Obtendo o tipo da nossa variável
type(marcas)
# Out:
# list

# %%
marcas
# Out:
# [{'nome': 'Acura', 'codigo': '1'},
#  {'nome': 'Agrale', 'codigo': '2'},
#  {'nome': 'Alfa Romeo', 'codigo': '3'},
#  {'nome': 'AM Gen', 'codigo': '4'},
#  {'nome': 'Asia Motors', 'codigo': '5'},
#  {'nome': 'ASTON MARTIN', 'codigo': '189'},
#  {'nome': 'Audi', 'codigo': '6'},
#  {'nome': 'Baby', 'codigo': '207'},
#  {'nome': 'BMW', 'codigo': '7'},
#  {'nome': 'BRM', 'codigo': '8'},
#  {'nome': 'Bugre', 'codigo': '123'},
#  {'nome': 'BYD', 'codigo': '238'},
#  {'nome': 'CAB Motors', 'codigo': '236'},
#  {'nome': 'Cadillac', 'codigo': '10'},
#  {'nome': 'Caoa Chery', 'codigo': '161'},
#  {'nome': 'CBT Jipe', 'codigo': '11'},
#  {'nome': 'CHANA', 'codigo': '136'},
#  {'nome': 'CHANGAN', 'codigo': '182'},
#  {'nome': 'Chrysler', 'codigo': '12'},
#  {'nome': 'Citroën', 'codigo': '13'},
#  {'nome': 'Cross Lander', 'codigo': '14'},
#  {'nome': 'Daewoo', 'codigo': '15'},
#  {'nome': 'Daihatsu', 'codigo': '16'},
#  {'nome': 'Dodge', 'codigo': '17'},
#  {'nome': 'EFFA', 'codigo': '147'},
#  {'nome': 'Engesa', 'codigo': '18'},
#  {'nome': 'Envemo', 'codigo': '19'},
#  {'nome': 'Ferrari', 'codigo': '20'},
#  {'nome': 'Fiat', 'codigo': '21'},
#  {'nome': 'Fibravan', 'codigo': '149'},
#  {'nome': 'Ford', 'codigo': '22'},
#  {'nome': 'FOTON', 'codigo': '190'},
#  {'nome': 'Fyber', 'codigo': '170'},
#  {'nome': 'GEELY', 'codigo': '199'},
#  {'nome': 'GM - Chevrolet', 'codigo': '23'},
#  {'nome': 'GREAT WALL', 'codigo': '153'},
#  {'nome': 'Gurgel', 'codigo': '24'},
#  {'nome': 'HAFEI', 'codigo': '152'},
#  {'nome': 'HITECH ELECTRIC', 'codigo': '214'},
#  {'nome': 'Honda', 'codigo': '25'},
#  {'nome': 'Hyundai', 'codigo': '26'},
#  {'nome': 'Isuzu', 'codigo': '27'},
#  {'nome': 'IVECO', 'codigo': '208'},
#  {'nome': 'JAC', 'codigo': '177'},
#  {'nome': 'Jaguar', 'codigo': '28'},
#  {'nome': 'Jeep', 'codigo': '29'},
#  {'nome': 'JINBEI', 'codigo': '154'},
#  {'nome': 'JPX', 'codigo': '30'},
#  {'nome': 'Kia Motors', 'codigo': '31'},
#  {'nome': 'Lada', 'codigo': '32'},
#  {'nome': 'LAMBORGHINI', 'codigo': '171'},
#  {'nome': 'Land Rover', 'codigo': '33'},
#  {'nome': 'Lexus', 'codigo': '34'},
#  {'nome': 'LIFAN', 'codigo': '168'},
#  {'nome': 'LOBINI', 'codigo': '127'},
#  {'nome': 'Lotus', 'codigo': '35'},
#  {'nome': 'Mahindra', 'codigo': '140'},
#  {'nome': 'Maserati', 'codigo': '36'},
#  {'nome': 'Matra', 'codigo': '37'},
#  {'nome': 'Mazda', 'codigo': '38'},
#  {'nome': 'Mclaren', 'codigo': '211'},
#  {'nome': 'Mercedes-Benz', 'codigo': '39'},
#  {'nome': 'Mercury', 'codigo': '40'},
#  {'nome': 'MG', 'codigo': '167'},
#  {'nome': 'MINI', 'codigo': '156'},
#  {'nome': 'Mitsubishi', 'codigo': '41'},
#  {'nome': 'Miura', 'codigo': '42'},
#  {'nome': 'Nissan', 'codigo': '43'},
#  {'nome': 'Peugeot', 'codigo': '44'},
#  {'nome': 'Plymouth', 'codigo': '45'},
#  {'nome': 'Pontiac', 'codigo': '46'},
#  {'nome': 'Porsche', 'codigo': '47'},
#  {'nome': 'RAM', 'codigo': '185'},
#  {'nome': 'RELY', 'codigo': '186'},
#  {'nome': 'Renault', 'codigo': '48'},
#  {'nome': 'Rolls-Royce', 'codigo': '195'},
#  {'nome': 'Rover', 'codigo': '49'},
#  {'nome': 'Saab', 'codigo': '50'},
#  {'nome': 'Saturn', 'codigo': '51'},
#  {'nome': 'Seat', 'codigo': '52'},
#  {'nome': 'SHINERAY', 'codigo': '183'},
#  {'nome': 'smart', 'codigo': '157'},
#  {'nome': 'SSANGYONG', 'codigo': '125'},
#  {'nome': 'Subaru', 'codigo': '54'},
#  {'nome': 'Suzuki', 'codigo': '55'},
#  {'nome': 'TAC', 'codigo': '165'},
#  {'nome': 'Toyota', 'codigo': '56'},
#  {'nome': 'Troller', 'codigo': '57'},
#  {'nome': 'Volvo', 'codigo': '58'},
#  {'nome': 'VW - VolksWagen', 'codigo': '59'},
#  {'nome': 'Wake', 'codigo': '163'},
#  {'nome': 'Walk', 'codigo': '120'}]

# %%
# Iterando sobre a lista que contém o nome da marca 
# e seu respectivo código
for marca in marcas:
    print("Marca:", marca["nome"], "Codigo:", marca["codigo"])
# Out:
# Marca: Acura Codigo: 1
# Marca: Agrale Codigo: 2
# Marca: Alfa Romeo Codigo: 3
# Marca: AM Gen Codigo: 4
# Marca: Asia Motors Codigo: 5
# Marca: ASTON MARTIN Codigo: 189
# Marca: Audi Codigo: 6
# Marca: Baby Codigo: 207
# Marca: BMW Codigo: 7
# Marca: BRM Codigo: 8
# Marca: Bugre Codigo: 123
# Marca: BYD Codigo: 238
# Marca: CAB Motors Codigo: 236
# Marca: Cadillac Codigo: 10
# Marca: Caoa Chery Codigo: 161
# Marca: CBT Jipe Codigo: 11
# Marca: CHANA Codigo: 136
# Marca: CHANGAN Codigo: 182
# Marca: Chrysler Codigo: 12
# Marca: Citroën Codigo: 13
# Marca: Cross Lander Codigo: 14
# Marca: Daewoo Codigo: 15
# Marca: Daihatsu Codigo: 16
# Marca: Dodge Codigo: 17
# Marca: EFFA Codigo: 147
# Marca: Engesa Codigo: 18
# Marca: Envemo Codigo: 19
# Marca: Ferrari Codigo: 20
# Marca: Fiat Codigo: 21
# Marca: Fibravan Codigo: 149
# Marca: Ford Codigo: 22
# Marca: FOTON Codigo: 190
# Marca: Fyber Codigo: 170
# Marca: GEELY Codigo: 199
# Marca: GM - Chevrolet Codigo: 23
# Marca: GREAT WALL Codigo: 153
# Marca: Gurgel Codigo: 24
# Marca: HAFEI Codigo: 152
# Marca: HITECH ELECTRIC Codigo: 214
# Marca: Honda Codigo: 25
# Marca: Hyundai Codigo: 26
# Marca: Isuzu Codigo: 27
# Marca: IVECO Codigo: 208
# Marca: JAC Codigo: 177
# Marca: Jaguar Codigo: 28
# Marca: Jeep Codigo: 29
# Marca: JINBEI Codigo: 154
# Marca: JPX Codigo: 30
# Marca: Kia Motors Codigo: 31
# Marca: Lada Codigo: 32
# Marca: LAMBORGHINI Codigo: 171
# Marca: Land Rover Codigo: 33
# Marca: Lexus Codigo: 34
# Marca: LIFAN Codigo: 168
# Marca: LOBINI Codigo: 127
# Marca: Lotus Codigo: 35
# Marca: Mahindra Codigo: 140
# Marca: Maserati Codigo: 36
# Marca: Matra Codigo: 37
# Marca: Mazda Codigo: 38
# Marca: Mclaren Codigo: 211
# Marca: Mercedes-Benz Codigo: 39
# Marca: Mercury Codigo: 40
# Marca: MG Codigo: 167
# Marca: MINI Codigo: 156
# Marca: Mitsubishi Codigo: 41
# Marca: Miura Codigo: 42
# Marca: Nissan Codigo: 43
# Marca: Peugeot Codigo: 44
# Marca: Plymouth Codigo: 45
# Marca: Pontiac Codigo: 46
# Marca: Porsche Codigo: 47
# Marca: RAM Codigo: 185
# Marca: RELY Codigo: 186
# Marca: Renault Codigo: 48
# Marca: Rolls-Royce Codigo: 195
# Marca: Rover Codigo: 49
# Marca: Saab Codigo: 50
# Marca: Saturn Codigo: 51
# Marca: Seat Codigo: 52
# Marca: SHINERAY Codigo: 183
# Marca: smart Codigo: 157
# Marca: SSANGYONG Codigo: 125
# Marca: Subaru Codigo: 54
# Marca: Suzuki Codigo: 55
# Marca: TAC Codigo: 165
# Marca: Toyota Codigo: 56
# Marca: Troller Codigo: 57
# Marca: Volvo Codigo: 58
# Marca: VW - VolksWagen Codigo: 59
# Marca: Wake Codigo: 163
# Marca: Walk Codigo: 120

# %%
# Instanciando a URL para obter os modelos através do ID da marca
# selecionada
url_carros = "https://parallelum.com.br/fipe/api/v1/carros/marcas/6/modelos"

# Obtendo informações da API através do método GET
response = requests.get(url_carros, headers=headers)

# Salvando a resposta da API
carros = response.json()

# %%
# Obtendo o tipo da nossa variável
type(carros)
# Out:
# dict

# %%
# Por se tratar de um Dict, iremos obter as Chaves desse dict
# para analisarmos qual temos interesse
carros.keys()
# Out:
# dict_keys(['modelos', 'anos'])

# %%
# Analisando nosso Dict para a Chave 'modelos'
carros['modelos']
# Out:
# [{'nome': '100 2.8 V6', 'codigo': 43},
#  {'nome': '100 2.8 V6 Avant', 'codigo': 44},
#  {'nome': '100 S-4 2.2 Avant Turbo', 'codigo': 45},
#  {'nome': '80 2.0', 'codigo': 46},
#  {'nome': '80 2.0 Avant', 'codigo': 47},
#  {'nome': '80 2.6/ 2.8', 'codigo': 48},
#  {'nome': '80 2.6/2.8 Avant', 'codigo': 49},
#  {'nome': '80 2.8 Cabriolet', 'codigo': 50},
#  {'nome': '80 S2 Avant', 'codigo': 51},
#  {'nome': 'A1 1.4 TFSI 122cv S-tronic 3p', 'codigo': 5496},
#  {'nome': 'A1 2.0 TFSI Quattro 256cv 3p', 'codigo': 6293},
#  {'nome': 'A1 Sport 1.4 TFSI 185cv 3p S-tronic', 'codigo': 6143},
#  {'nome': 'A1 Sport. S Edition 1.4 TFSI 5p S-tronic', 'codigo': 7727},
#  {'nome': 'A1 Sportback 1.4 TFSI 185cv 5p S-tronic', 'codigo': 6201},
#  {'nome': 'A1 Sportback 1.4 TFSI 5p S-tronic', 'codigo': 6200},
#  {'nome': 'A1 Sportback 1.8 TFSI 192cv 5p S-tronic', 'codigo': 7418},
#  {'nome': 'A3 1.6 3p', 'codigo': 52},
#  {'nome': 'A3 1.6 3p Aut.', 'codigo': 53},
#  {'nome': 'A3 1.6 5p', 'codigo': 54},
#  {'nome': 'A3 1.6 5p Aut.', 'codigo': 55},
#  {'nome': 'A3 1.6 8V 102cv 3p', 'codigo': 4154},
#  {'nome': 'A3 1.8 3p', 'codigo': 56},
#  {'nome': 'A3 1.8 3p Aut.', 'codigo': 57},
#  {'nome': 'A3 1.8 5p Aut.', 'codigo': 58},
#  {'nome': 'A3 1.8 5p Mec.', 'codigo': 59},
#  {'nome': 'A3 1.8 Turbo 180cv 3p Aut./ Tip.', 'codigo': 60},
#  {'nome': 'A3 1.8 Turbo 180cv 3p Mec.', 'codigo': 61},
#  {'nome': 'A3 1.8 Turbo 180cv 5p Aut./ Tip.', 'codigo': 62},
#  {'nome': 'A3 1.8 Turbo 180cv 5p Mec.', 'codigo': 63},
#  {'nome': 'A3 1.8 Turbo 3p Aut.', 'codigo': 64},
#  {'nome': 'A3 1.8 Turbo 3p Mec.', 'codigo': 65},
#  {'nome': 'A3 1.8 Turbo 5p Aut.', 'codigo': 66},
#  {'nome': 'A3 1.8 Turbo 5p Mec.', 'codigo': 67},
#  {'nome': 'A3 Cabriolet 1.8 16V TFSI 180cv S-tronic', 'codigo': 6950},
#  {'nome': 'A3 Cabriolet Ambition 2.0 TFSI S-tronic', 'codigo': 8227},
#  {'nome': 'A3 Cabriolet Perfor. 2.0 TFSI S-tronic', 'codigo': 8559},
#  {'nome': 'A3 Sed. Ambition 2.0 TSFI 220cv S-tronic', 'codigo': 7419},
#  {'nome': 'A3 Sed. P. Plus Tech 1.4 Flex TFSI Tip.', 'codigo': 8945},
#  {'nome': 'A3 Sed. P.Plus 1.4 25anos Flex TFSI Tip.', 'codigo': 8768},
#  {'nome': 'A3 Sed.1.8/1.8 Ambit.16V TB FSI S-tronic', 'codigo': 6689},
#  {'nome': 'A3 Sed.Perf. Black 2.0 TFSI S-tr. (Hib.)', 'codigo': 10195},
#  {'nome': 'A3 Sedan 1.4 TFSI Flex Tiptronic 4p', 'codigo': 7391},
#  {'nome': 'A3 Sedan 1.4/ Attra. 16V TB FSI S-tronic', 'codigo': 6768},
#  {'nome': 'A3 Sedan Performance 2.0 TFSI S-tronic', 'codigo': 8560},
#  {'nome': 'A3 Sedan Prestige 1.4 TFSI Flex Tip.', 'codigo': 8561},
#  {'nome': 'A3 Sedan Prestige Plus 1.4 TFSI Flex Tip', 'codigo': 8562},
#  {'nome': 'A3 Sedan S-Line 2.0 TFSI  S-Tron.(Híb.)', 'codigo': 9963},
#  {'nome': 'A3 Sedan S-Line Limited 1.4 TFSI Tiptro.', 'codigo': 9655},
#  {'nome': 'A3 Sport 1.8 16V TFSI S-tronic 3p', 'codigo': 6461},
#  {'nome': 'A3 Sport 2.0 16V TFSI S- tronic', 'codigo': 5125},
#  {'nome': 'A3 Sportb. Perf. Black 2.0 S-tron.(Híb.)', 'codigo': 9964},
#  {'nome': 'A3 Sportb. Prestige Plus 1.4 TFSI S-tron', 'codigo': 8563},
#  {'nome': 'A3 Sportb. S-Line 2.0 TFSI S-Tron.(Híb.)', 'codigo': 9965},
#  {'nome': 'A3 Sportb. S-Line Limited 1.4 TFSI Tip.', 'codigo': 9657},
#  {'nome': 'A3 Sportback 1.4 TFSI S-tronic', 'codigo': 6510},
#  {'nome': 'A3 Sportback 1.6 8V 102cv 5p', 'codigo': 4155},
#  {'nome': 'A3 Sportback 1.8 16V TFSI S-tronic 5p', 'codigo': 6511},
#  {'nome': 'A3 Sportback 2.0 16V TFSI Mec.', 'codigo': 4156},
#  {'nome': 'A3 Sportback 2.0 16V TFSI S-tronic', 'codigo': 4157},
#  {'nome': 'A4 1.8  Aut.', 'codigo': 68},
#  {'nome': 'A4 1.8  Mec.', 'codigo': 69},
#  {'nome': 'A4 1.8 Avant Aut.', 'codigo': 70},
#  {'nome': 'A4 1.8 Avant Mec.', 'codigo': 71},
#  {'nome': 'A4 1.8 Avant Turbo Mec.', 'codigo': 72},
#  {'nome': 'A4 1.8 Avant Turbo Tip./ Multitronic', 'codigo': 73},
#  {'nome': 'A4 1.8 Tip./ Multitronic Turbo', 'codigo': 74},
#  {'nome': 'A4 1.8 Turbo', 'codigo': 75},
#  {'nome': 'A4 2.0 16V TFSI 183/180cv Multitronic', 'codigo': 4843},
#  {'nome': 'A4 2.0 16V TFSI 200/ 214cv Multitronic', 'codigo': 4182},
#  {'nome': 'A4 2.0 16V TFSI Quattro Stronic', 'codigo': 6144},
#  {'nome': 'A4 2.0 20V 130cv Multitronic 4p', 'codigo': 76},
#  {'nome': 'A4 2.0 Avant 16V TFSI Quattro Stronic', 'codigo': 6145},
#  {'nome': 'A4 2.0 Avant Ambie. 2.0 16V TFSi S tron.', 'codigo': 7750},
#  {'nome': 'A4 2.0 Avant TFSI 183/180cv Multitroni', 'codigo': 4844},
#  {'nome': 'A4 2.0 Avant TFSI 200/214cv Multitron.', 'codigo': 4183},
#  {'nome': 'A4 2.4 30V Avant Mec.', 'codigo': 77},
#  {'nome': 'A4 2.4 30V Avant Tip./Multitronic', 'codigo': 78},
#  {'nome': 'A4 2.4 30V Mec.', 'codigo': 79},
#  {'nome': 'A4 2.4 30V Tip./Multitronic', 'codigo': 80},
#  {'nome': 'A4 2.4 Avant V6 30V Quattro Mec.', 'codigo': 81},
#  {'nome': 'A4 2.4 Avant V6 30V Quattro Tiptronic', 'codigo': 82},
#  {'nome': 'A4 2.4 V6 30V Quattro Mec.', 'codigo': 83},
#  {'nome': 'A4 2.4 V6 30V Quattro Tiptronic', 'codigo': 84},
#  {'nome': 'A4 2.8', 'codigo': 85},
#  {'nome': 'A4 2.8 30V  Tiptronic/ Aut.', 'codigo': 86},
#  {'nome': 'A4 2.8 30V Mec.', 'codigo': 87},
#  {'nome': 'A4 2.8 Avant V6 12V', 'codigo': 88},
#  {'nome': 'A4 2.8 Avant V6 30V Mec.', 'codigo': 89},
#  {'nome': 'A4 2.8 Avant V6 30V Quattro Mec.', 'codigo': 90},
#  {'nome': 'A4 2.8 Avant V6 30V Quattro Tiptronic', 'codigo': 91},
#  {'nome': 'A4 2.8 Avant V6 30V Tiptronic', 'codigo': 92},
#  {'nome': 'A4 2.8 V6 30V  Quattro Tiptronic', 'codigo': 93},
#  {'nome': 'A4 2.8 V6 30V Quattro Mec.', 'codigo': 94},
#  {'nome': 'A4 3.0 30V 218cv Multitronic 4p', 'codigo': 95},
#  {'nome': 'A4 3.0 30V 218cv Quattro Tiptron./Aut 4p', 'codigo': 96},
#  {'nome': 'A4 3.0 Avant 30V 218cv Multitronic 5p', 'codigo': 97},
#  {'nome': 'A4 3.0 Avant 30V 218cv Quattro Tiptronic', 'codigo': 98},
#  {'nome': 'A4 3.0 Cabriolet 30V 218cv Multitronic', 'codigo': 99},
#  {'nome': 'A4 3.2 FSI 24V 255cv Multitronic', 'codigo': 4286},
#  {'nome': 'A4 3.2 FSI 24V 269cv Quattro Tiptronic', 'codigo': 4731},
#  {'nome': 'A4 3.2 FSI Avant 24V 255cv Multitronic', 'codigo': 4287},
#  {'nome': 'A4 3.2 FSI Avant 24V Quattro S Tronic', 'codigo': 4935},
#  {'nome': 'A4 3.2 FSI Cabriolet 24V 255cv Multitron', 'codigo': 4288},
#  {'nome': 'A4 Ambiente 2.0 TFSI 190cv S tronic', 'codigo': 7717},
#  {'nome': 'A4 Ambition 2.0 TFSI Quattro S tronic', 'codigo': 7894},
#  {'nome': 'A4 Attraction 2.0 TFSI 190cv S tronic', 'codigo': 7656},
#  {'nome': 'A4 Avant Lim. Ed. 2.0 TFSI S tronic', 'codigo': 8228},
#  {'nome': 'A4 Avant Prest. Plus 2.0 TFSI S-tronic', 'codigo': 8769},
#  {'nome': 'A4 Launch Edition 2.0 TFSI 190cv S troni', 'codigo': 7537},
#  {'nome': 'A4 Limited Edition 2.0 TFSI S tronic', 'codigo': 8229},
#  {'nome': 'A4 Perfor. Black 2.0 TFSI Quat. S tronic', 'codigo': 9223},
#  {'nome': 'A4 Prestige 2.0 TFSI S-tronic', 'codigo': 9894},
#  {'nome': 'A4 Prestige Plus 2.0 TFSI 190cv S tronic', 'codigo': 8771},
#  {'nome': 'A4 S Line 2.0  TFSI 204cv S Tonic', 'codigo': 9824},
#  {'nome': 'A5 3.2 FSI 24V 269cv Multitronic', 'codigo': 4798},
#  {'nome': 'A5 3.2 FSI V6 24V 269cv Quattro Tiptroni', 'codigo': 5126},
#  {'nome': 'A5 Ambiente Sportb. 2.0 TFSI S tonic', 'codigo': 7999},
#  {'nome': 'A5 Ambit. Plus Sport. 2.0 TFSI S tronic', 'codigo': 8000},
#  {'nome': 'A5 Ambit. Sport. 2.0 TFSI S tronic', 'codigo': 8001},
#  {'nome': 'A5 Attraction Sportb. 2.0 TFSI S tronic', 'codigo': 8002},
#  {'nome': 'A5 Cabriolet 2.0 TFSI Quattro Stronic', 'codigo': 6082},
#  {'nome': 'A5 Coupê 2.0 TFSI Quattro Stronic', 'codigo': 6083},
#  {'nome': 'A5 Sportb. 2.0 16V TFSI Quat. S-tronic', 'codigo': 6084},
#  {'nome': 'A5 Sportb. Perf. 2.0 TFSI Quat. S-tronic', 'codigo': 8564},
#  {'nome': 'A5 Sportb. Prestige 2.0 16V TFSI S-troni', 'codigo': 8565},
#  {'nome': 'A5 Sportb.Perf.B. 2.0 TFSI Quat. S-troni', 'codigo': 8566},
#  {'nome': 'A5 Sportb.Prestige Plus 2.0 TFSI S-tronc', 'codigo': 8567},
#  {'nome': 'A5 Sportback 1.8 TFSI 170cv Multi.', 'codigo': 7022},
#  {'nome': 'A5 Sportback 2.0 16V TFSI 180cv Multi.', 'codigo': 6043},
#  {'nome': 'A5 Sportback 2.0 16V TFSI 211cv Multi.', 'codigo': 5234},
#  {'nome': 'A5 Sportback S-Line 2.0 TFSI S-tronic', 'codigo': 8772},
#  {'nome': 'A6 2.0 TFSI 252cv S tronic 4p', 'codigo': 7254},
#  {'nome': 'A6 2.4 30V Mec', 'codigo': 100},
#  {'nome': 'A6 2.4 30V Tip./Multitronic', 'codigo': 101},
#  {'nome': 'A6 2.4 Avant 30V Mec.', 'codigo': 102},
#  {'nome': 'A6 2.4 Avant 30V Tip./ Multitronic', 'codigo': 103},
#  {'nome': 'A6 2.4 Avant V6 30V Quattro Mec.', 'codigo': 104},
#  {'nome': 'A6 2.4 Avant V6 30V Quattro Tiptronic', 'codigo': 105},
#  {'nome': 'A6 2.4 V6 30V Quattro Mec', 'codigo': 106},
#  {'nome': 'A6 2.4 V6 30V Quattro Tiptronic', 'codigo': 107},
#  {'nome': 'A6 2.7 30V Avant Tiptronic', 'codigo': 108},
#  {'nome': 'A6 2.7 30V Mec.', 'codigo': 109},
#  {'nome': 'A6 2.7 Avant Quattro Tiptronic', 'codigo': 110},
#  {'nome': 'A6 2.7 Quattro Tiptronic', 'codigo': 111},
#  {'nome': 'A6 2.8', 'codigo': 112},
#  {'nome': 'A6 2.8 30V Mec.', 'codigo': 113},
#  {'nome': 'A6 2.8 30V Tiptronic', 'codigo': 114},
#  {'nome': 'A6 2.8 Avant', 'codigo': 115},
#  {'nome': 'A6 2.8 Avant 30V Mec.', 'codigo': 116},
#  {'nome': 'A6 2.8 Avant 30V Tiptronic', 'codigo': 117},
#  {'nome': 'A6 2.8 Avant V6 30V Quattro Mec.', 'codigo': 118},
#  {'nome': 'A6 2.8 Avant V6 30V Quattro Tiptronic', 'codigo': 119},
#  {'nome': 'A6 2.8 V6 30V Quattro Mec.', 'codigo': 120},
#  {'nome': 'A6 2.8 V6 30V Quattro Tiptronic', 'codigo': 121},
#  {'nome': 'A6 3.0 Avant V6 30V 218cv Multitronic 5p', 'codigo': 122},
#  {'nome': 'A6 3.0 Avant. TB FSI V6 Quattro Tip. 5p', 'codigo': 5374},
#  {'nome': 'A6 3.0 Avant.TFSI V6 Quattro S tronic 5p', 'codigo': 6413},
#  {'nome': 'A6 3.0 TB FSI V6 Quattro Tiptronic', 'codigo': 4958},
#  {'nome': 'A6 3.0 TFSI V6 Quattro S tronic 4p', 'codigo': 6414},
#  {'nome': 'A6 3.0 V6 30V 218cv Multitronic 4p', 'codigo': 123},
#  {'nome': 'A6 3.2 FSI 24V 255cv Multitronic', 'codigo': 4526},
#  {'nome': 'A6 4.2 Avant Quattro Tiptronic', 'codigo': 124},
#  {'nome': 'A6 4.2 Quattro Tiptronic', 'codigo': 125},
#  {'nome': 'A6 Allroad 3.0 TFSI V6 Quattro S tronic', 'codigo': 6462},
#  {'nome': 'A6 Perf. Black 3.0 TFSI Quattro S-tronic', 'codigo': 9298},
#  {'nome': 'A6 Performance 3.0 TFSI Quattro S.tronic', 'codigo': 8814},
#  {'nome': 'A6 Prestige Plus 2.0 TFSI Quattro S-tro.', 'codigo': 9451},
#  {'nome': 'A7 SP.b. Perf. Bla. 3.0 TFSI Quat. S-tro', 'codigo': 9319},
#  {'nome': 'A7 Sportback 2.0 TFSI S Tronic', 'codigo': 7447},
#  {'nome': 'A7 Sportback 3.0 TFSI Quattro S Tronic', 'codigo': 5549},
#  {'nome': 'A7 Sportback Perf. 3.0 TFSI S-tron Quat.', 'codigo': 8815},
#  {'nome': 'A8 3.0 TFSI 310cv Quattro Tiptronic 4p', 'codigo': 7127},
#  {'nome': 'A8 4.0 TFSI Quattro Tiptronic', 'codigo': 6631},
#  {'nome': 'A8 4.2 Quattro Tiptronic', 'codigo': 126},
#  {'nome': 'A8 4.2 V8 32V Tiptronic', 'codigo': 127},
#  {'nome': 'A8 6.0 W12 48V 450cv Quattro Tiptronic', 'codigo': 3928},
#  {'nome': 'A8 6.3 W12 48V Quattro Tiptronic', 'codigo': 5717},
#  {'nome': 'Allroad 2.7 30V Quattro Turbo Tiptronic', 'codigo': 128},
#  {'nome': 'Avant RS2', 'codigo': 129},
#  {'nome': 'E-TRON Performa. Black Aut. (Elétrico)', 'codigo': 9077},
#  {'nome': 'E-TRON Performace Aut. (Elétrico)', 'codigo': 9078},
#  {'nome': 'E-TRON S Sportback Quat. Aut. (Elétrico)', 'codigo': 9605},
#  {'nome': 'E-TRON Sportb. Perf.Black Aut.(Elétrico)', 'codigo': 9186},
#  {'nome': 'E-TRON Sportback Perf. Aut. (Elétrico)', 'codigo': 9187},
#  {'nome': 'Q3 1.4 TFSI/TFSI Flex S-tronic 5p', 'codigo': 7255},
#  {'nome': 'Q3 2.0 TFSI Quat. 170/180cv S-tronic 5p', 'codigo': 6044},
#  {'nome': 'Q3 2.0 TFSI Quat. 211/220cv S-tronic 5p', 'codigo': 6045},
#  {'nome': 'Q3 Black Ed. 1.4 TFSI Flex/Black S-tron.', 'codigo': 8230},
#  {'nome': 'Q3 Black S Line 1.4 TFSI S-tronic', 'codigo': 9304},
#  {'nome': 'Q3 P. Plus 1.4 TFSI Flex/P.Plus S-tronic', 'codigo': 8569},
#  {'nome': 'Q3 Perf. Black 2.0 TFSI Tiptr. Quattro', 'codigo': 9796},
#  {'nome': 'Q3 Performance 2.0 TFSI Tiptr. Quattro', 'codigo': 9871},
#  {'nome': 'Q3 Prest. 1.4 TFSI Flex/Prest. S-tronic', 'codigo': 8568},
#  {'nome': 'Q3 Prestige 2.0 TFSI Tiptr.Quatro ', 'codigo': 10111},
#  {'nome': 'Q3 SPB Perf. Black 2.0 TFSI Tipt. Quat.', 'codigo': 9835},
#  {'nome': 'Q3 SPB Performance 2.0 TFSI Tipt. Quatt.', 'codigo': 9836},
#  {'nome': 'Q5 2.0 16V TFSI 225cv Quattro Tiptronic', 'codigo': 6573},
#  {'nome': 'Q5 2.0 16V TFSI Quattro S Tronic', 'codigo': 4936},
#  {'nome': 'Q5 2.0 TFSI Quattro S tronic (Blindado)', 'codigo': 8231},
#  {'nome': 'Q5 3.0 V6 TFSI 272cv Quattro Tiptronic', 'codigo': 6486},
#  {'nome': 'Q5 3.2 FSI V6 Quattro S Tronic', 'codigo': 4959},
#  {'nome': 'Q5 Ambiente 2.0 TFSI Quattro S tronic', 'codigo': 8036},
#  {'nome': 'Q5 Ambition 2.0 TFSI Quattro S tronic', 'codigo': 8037},
#  {'nome': 'Q5 Attraction 2.0 TFSI Quattro S tronic', 'codigo': 8038},
#  {'nome': 'Q5 Black 2.0 TFSI Quattro S tronic', 'codigo': 8583},
#  {'nome': 'Q5 Perf. Black 2.0 TFSIe S.Tr. Qt (Hib.)', 'codigo': 10045},
#  {'nome': 'Q5 Performance 2.0 TFSIe S.Tr. Qt (Hib.)', 'codigo': 10046},
#  {'nome': 'Q5 Prestige 2.0 TFSI Quattro S tronic', 'codigo': 8584},
#  {'nome': 'Q5 Prestige Plus 2.0 TFSI Quat. S tronic', 'codigo': 8585},
#  {'nome': 'Q5 SB P Black. 2.0 TFSIe S.Tr. Qt (Hib.)', 'codigo': 10047},
#  {'nome': 'Q5 SB Perf. 2.0 TFSIe S.Tr. Qt (Hib.)', 'codigo': 10048},
#  {'nome': 'Q5 S-Line 2.0 TFSI Quattro S-tronic', 'codigo': 8773},
#  {'nome': 'Q5 S-Line Black 2.0 TFSI Quat. S-Tronic', 'codigo': 9486},
#  {'nome': 'Q5 SPB. S-Line Black 2.0 TFSI Qua.S-Tron', 'codigo': 9526},
#  {'nome': 'Q5 Sportback S-Line 2.0 TFSI Quat.S-Tron', 'codigo': 9527},
#  {'nome': 'Q7 3.0 V6 TDI Quat.Tip. 5p Die./Perfor.', 'codigo': 7917},
#  {'nome': 'Q7 3.0 V6 TFSI  Quat.Tip.5p/ Perf.(Híb.)', 'codigo': 10049},
#  {'nome': 'Q7 3.6 V6 284cv Quattro Tiptronic', 'codigo': 4694},
#  {'nome': 'Q7 4.2 V8 40V 350cv Quattro Tiptronic', 'codigo': 4184},
#  {'nome': 'Q7 Perf. Black 3.0 TFSI Quat.Tip.(Híb.)', 'codigo': 10050},
#  {'nome': 'Q7 Perf.Black 3.0 TDI Quat.Tip.5p Dies.', 'codigo': 8658},
#  {'nome': 'Q7 S-Line 3.0 V6 TFSI Quattro Tiptronic', 'codigo': 9205},
#  {'nome': 'Q8 Perf.Black 3.0 TFSI Quat. S-tr.(Híb.)', 'codigo': 10051},
#  {'nome': 'Q8 Perfo. 3.0 TFSI Quattro S-tron.(Híb.)', 'codigo': 10052},
#  {'nome': 'R8 4.2 V8 426cv Quattro R-tronic', 'codigo': 5235},
#  {'nome': 'R8 5.2 V10 Quattro R-tronic/S-tronic', 'codigo': 5236},
#  {'nome': 'R8 GT 5.2 V10 560cv Quattro R-tronic', 'codigo': 5974},
#  {'nome': 'R8 Spyder 5.2 Quattro R-tronic/S-tronic', 'codigo': 5550},
#  {'nome': 'RS E-TRON GT Quattro Aut. (Elétrico)', 'codigo': 9606},
#  {'nome': 'RS Q3 2.5 TFSI Quattro S-tronic 5p', 'codigo': 6865},
#  {'nome': 'RS Q3 Sportback 2.5 TFSI Quattro S-tron.', 'codigo': 9292},
#  {'nome': 'RS Q8 4.0 Bi-TB V8 FSI Quattro Tiptronic', 'codigo': 9224},
#  {'nome': 'RS3 Sedan 2.5 TFSI Quattro S-tronic', 'codigo': 8175},
#  {'nome': 'RS3 Sportback 2.5 TFSI Quattro S-tronic', 'codigo': 5922},
#  {'nome': 'RS4 2.7 Avant V6 30V BI-TB Quattro 380cv', 'codigo': 130},
#  {'nome': 'RS4 2.9 Avant V6 TFSI Quattro Tiptronic', 'codigo': 8628},
#  {'nome': 'RS4 4.2 Avant 32V FSI Quattro S-tronic', 'codigo': 6487},
#  {'nome': 'RS5 4.2 FSI V8 450cv Quattro S-Tron. 2p', 'codigo': 5410},
#  {'nome': 'RS5 Coupê 2.9 V6 TFSI Quattro Tiptronic', 'codigo': 8629},
#  {'nome': 'RS5 Sportback 2.9 V6 TFSI Quattro Tip.', 'codigo': 9247},
#  {'nome': 'RS6 4.0 Avant TFSI BI-TB Quat.Tip.(Hib.)', 'codigo': 10227},
#  {'nome': 'RS6 4.2 450cv BI-TB Quattro Tiptronic 4p', 'codigo': 131},
#  {'nome': 'RS6 4.2 Avant  BI-TB Quattro Tiptron. 5p', 'codigo': 132},
#  {'nome': 'RS6 5.0 Avant.FSI V10 Bi-TB Quattro Tip.', 'codigo': 5335},
#  {'nome': 'RS6 5.0 FSI V10 Bi-TB Quattro Tip.', 'codigo': 5336},
#  {'nome': 'RS7 Sportback 4.0 TFSI Quattro Tiptronic', 'codigo': 6883},
#  {'nome': 'S Q5 3.0 V6 TFSI 354cv Quattro Tiptronic', 'codigo': 6769},
#  {'nome': 'S3 1.8 225cv Turbo Quattro', 'codigo': 133},
#  {'nome': 'S3 Sedan 2.0 TFSI Quattro 286cv S-tronic', 'codigo': 6951},
#  {'nome': 'S3 Sportback 2.0 TFSI Quattro S Tronic', 'codigo': 5127},
#  {'nome': 'S4 2.7 Avant Turbo Quattro', 'codigo': 134},
#  {'nome': 'S4 2.7 Turbo Quattro Mec.', 'codigo': 135},
#  {'nome': 'S4 3.0 Avant TFSI V6 24V Quattro Stronic', 'codigo': 6085},
#  {'nome': 'S4 3.0 TFSI V6 24V Quattro Stronic', 'codigo': 6086},
#  {'nome': 'S4 4.2 Avant V8 40V 344cv Quattro Tipt.', 'codigo': 136},
#  {'nome': 'S4 4.2 V8 40V 344cv Quattro Tiptronic', 'codigo': 137},
#  {'nome': 'S5 Cabriolet 3.0 TFSI Quattro Stronic', 'codigo': 6087},
#  {'nome': 'S5 Coupê 3.0 TFSI Quattro Stronic', 'codigo': 6088},
#  {'nome': 'S5 Sportback 3.0 TFSI Quattro Stronic', 'codigo': 6089},
#  {'nome': 'S6 2.2 20V TB', 'codigo': 138},
#  {'nome': 'S6 2.2 Avant 20V TB', 'codigo': 139},
#  {'nome': 'S6 4.0 TFSI Quattro S-Tronic 4p', 'codigo': 7302},
#  {'nome': 'S6 4.2 Avant V8 40V Quattro Tiptronic', 'codigo': 140},
#  {'nome': 'S6 4.2 V8 40V Quattro Mec', 'codigo': 141},
#  {'nome': 'S6 4.2 V8 40V Quattro Tiptronic', 'codigo': 142},
#  {'nome': 'S6 5.2 Avant FSI V10 435cv Quattro Tiptr', 'codigo': 5186},
#  {'nome': 'S6 5.2 FSI V10 435cv Quattro Tiptronic', 'codigo': 5187},
#  {'nome': 'S6 Plus 4.2 Avant V8 32V', 'codigo': 143},
#  {'nome': 'S6 Plus 4.2 V8 32V', 'codigo': 144},
#  {'nome': 'S7 4.0 TFSI 420/450cv Quattro S-tronic', 'codigo': 6632},
#  {'nome': 'S8 4.0 TFSI Quattro Tiptronic 4p', 'codigo': 7128},
#  {'nome': 'S8 4.2 Mec', 'codigo': 145},
#  {'nome': 'S8 4.2 Quattro Mec.', 'codigo': 146},
#  {'nome': 'S8 4.2 Quattro Tiptronic', 'codigo': 147},
#  {'nome': 'S8 4.2 Tiptronic', 'codigo': 148},
#  {'nome': 'TT 1.8 TB 180cv', 'codigo': 149},
#  {'nome': 'TT 1.8 TB Quattro 225cv', 'codigo': 150},
#  {'nome': 'TT 2.0 16v TFSI S-Tronic', 'codigo': 4330},
#  {'nome': 'TT Roadster 1.8 TB Quattro 225cv (Conv.)', 'codigo': 151},
#  {'nome': 'TT Roadster 2.0 16v TFSI S-Tronic', 'codigo': 4431},
#  {'nome': 'TTRS 2.5 TFSI QUATTRO S Tronic', 'codigo': 6258},
#  {'nome': 'TTRS Roadster 2.5 TB FSI Quat. S Tronic', 'codigo': 6259},
#  {'nome': 'TTS 2.0 TFSI QUATTRO S Tronic', 'codigo': 5128},
#  {'nome': 'TTS Roadster 2.0 TB FSI Quattro S Tronic', 'codigo': 5129}]

# %%
# Instanciando nossa classe para Iterar em nossa lista de Dicts

class FipeIterator:
    """
    Classe que itera sobre uma lista de dicionários de modelos de carros obtidos de uma API.
    
    Atributos:
        modelos (list): Lista de dicionários com informações sobre modelos de carros.
        current (int): Índice atual da lista de modelos.
        end (int): Tamanho da lista de modelos.
    
    Métodos:
        __iter__: Implementação padrão do método mágico __iter__.
        __next__: Implementação padrão do método mágico __next__.
    """
    def __init__(self, id_value: str):
        """
        Construtor da classe.
        
        Argumentos:
            id_value (str): Valor do ID da marca de carros a ser usado na URL da API.
        """
        
        # Desenvolvendo nossa URL com o ID passado
        url = "https://parallelum.com.br/fipe/api/v1/carros/marcas/{}/modelos"
        url = url.format(id_value)
        
        # Obtendo informações da API através do método GET
        response = requests.get(url_carros, headers=headers)

        # Salvando a resposta da API
        carros = response.json()
        
        # Obtendo valores para o Dict `modelos`
        self.modelos = carros['modelos']
        
        # Instanciando nosso estado atual e final
        self.current = 0
        self.end = len(self.modelos)

    def __iter__(self):
        return self

    def __next__(self):
        if self.current >= self.end:
            raise StopIteration
        result = self.modelos[self.current]
        self.current += 1
        return result

# %%
# Obtendo nosso iterador
iterator = FipeIterator("6")

# %%
# Iterando sobre nosso iterador
for modelo in iterator:
    print(modelo)
# Out:
# {'nome': '100 2.8 V6', 'codigo': 43}
# {'nome': '100 2.8 V6 Avant', 'codigo': 44}
# {'nome': '100 S-4 2.2 Avant Turbo', 'codigo': 45}
# {'nome': '80 2.0', 'codigo': 46}
# {'nome': '80 2.0 Avant', 'codigo': 47}
# {'nome': '80 2.6/ 2.8', 'codigo': 48}
# {'nome': '80 2.6/2.8 Avant', 'codigo': 49}
# {'nome': '80 2.8 Cabriolet', 'codigo': 50}
# {'nome': '80 S2 Avant', 'codigo': 51}
# {'nome': 'A1 1.4 TFSI 122cv S-tronic 3p', 'codigo': 5496}
# {'nome': 'A1 2.0 TFSI Quattro 256cv 3p', 'codigo': 6293}
# {'nome': 'A1 Sport 1.4 TFSI 185cv 3p S-tronic', 'codigo': 6143}
# {'nome': 'A1 Sport. S Edition 1.4 TFSI 5p S-tronic', 'codigo': 7727}
# {'nome': 'A1 Sportback 1.4 TFSI 185cv 5p S-tronic', 'codigo': 6201}
# {'nome': 'A1 Sportback 1.4 TFSI 5p S-tronic', 'codigo': 6200}
# {'nome': 'A1 Sportback 1.8 TFSI 192cv 5p S-tronic', 'codigo': 7418}
# {'nome': 'A3 1.6 3p', 'codigo': 52}
# {'nome': 'A3 1.6 3p Aut.', 'codigo': 53}
# {'nome': 'A3 1.6 5p', 'codigo': 54}
# {'nome': 'A3 1.6 5p Aut.', 'codigo': 55}
# {'nome': 'A3 1.6 8V 102cv 3p', 'codigo': 4154}
# {'nome': 'A3 1.8 3p', 'codigo': 56}
# {'nome': 'A3 1.8 3p Aut.', 'codigo': 57}
# {'nome': 'A3 1.8 5p Aut.', 'codigo': 58}
# {'nome': 'A3 1.8 5p Mec.', 'codigo': 59}
# {'nome': 'A3 1.8 Turbo 180cv 3p Aut./ Tip.', 'codigo': 60}
# {'nome': 'A3 1.8 Turbo 180cv 3p Mec.', 'codigo': 61}
# {'nome': 'A3 1.8 Turbo 180cv 5p Aut./ Tip.', 'codigo': 62}
# {'nome': 'A3 1.8 Turbo 180cv 5p Mec.', 'codigo': 63}
# {'nome': 'A3 1.8 Turbo 3p Aut.', 'codigo': 64}
# {'nome': 'A3 1.8 Turbo 3p Mec.', 'codigo': 65}
# {'nome': 'A3 1.8 Turbo 5p Aut.', 'codigo': 66}
# {'nome': 'A3 1.8 Turbo 5p Mec.', 'codigo': 67}
# {'nome': 'A3 Cabriolet 1.8 16V TFSI 180cv S-tronic', 'codigo': 6950}
# {'nome': 'A3 Cabriolet Ambition 2.0 TFSI S-tronic', 'codigo': 8227}
# {'nome': 'A3 Cabriolet Perfor. 2.0 TFSI S-tronic', 'codigo': 8559}
# {'nome': 'A3 Sed. Ambition 2.0 TSFI 220cv S-tronic', 'codigo': 7419}
# {'nome': 'A3 Sed. P. Plus Tech 1.4 Flex TFSI Tip.', 'codigo': 8945}
# {'nome': 'A3 Sed. P.Plus 1.4 25anos Flex TFSI Tip.', 'codigo': 8768}
# {'nome': 'A3 Sed.1.8/1.8 Ambit.16V TB FSI S-tronic', 'codigo': 6689}
# {'nome': 'A3 Sed.Perf. Black 2.0 TFSI S-tr. (Hib.)', 'codigo': 10195}
# {'nome': 'A3 Sedan 1.4 TFSI Flex Tiptronic 4p', 'codigo': 7391}
# {'nome': 'A3 Sedan 1.4/ Attra. 16V TB FSI S-tronic', 'codigo': 6768}
# {'nome': 'A3 Sedan Performance 2.0 TFSI S-tronic', 'codigo': 8560}
# {'nome': 'A3 Sedan Prestige 1.4 TFSI Flex Tip.', 'codigo': 8561}
# {'nome': 'A3 Sedan Prestige Plus 1.4 TFSI Flex Tip', 'codigo': 8562}
# {'nome': 'A3 Sedan S-Line 2.0 TFSI  S-Tron.(Híb.)', 'codigo': 9963}
# {'nome': 'A3 Sedan S-Line Limited 1.4 TFSI Tiptro.', 'codigo': 9655}
# {'nome': 'A3 Sport 1.8 16V TFSI S-tronic 3p', 'codigo': 6461}
# {'nome': 'A3 Sport 2.0 16V TFSI S- tronic', 'codigo': 5125}
# {'nome': 'A3 Sportb. Perf. Black 2.0 S-tron.(Híb.)', 'codigo': 9964}
# {'nome': 'A3 Sportb. Prestige Plus 1.4 TFSI S-tron', 'codigo': 8563}
# {'nome': 'A3 Sportb. S-Line 2.0 TFSI S-Tron.(Híb.)', 'codigo': 9965}
# {'nome': 'A3 Sportb. S-Line Limited 1.4 TFSI Tip.', 'codigo': 9657}
# {'nome': 'A3 Sportback 1.4 TFSI S-tronic', 'codigo': 6510}
# {'nome': 'A3 Sportback 1.6 8V 102cv 5p', 'codigo': 4155}
# {'nome': 'A3 Sportback 1.8 16V TFSI S-tronic 5p', 'codigo': 6511}
# {'nome': 'A3 Sportback 2.0 16V TFSI Mec.', 'codigo': 4156}
# {'nome': 'A3 Sportback 2.0 16V TFSI S-tronic', 'codigo': 4157}
# {'nome': 'A4 1.8  Aut.', 'codigo': 68}
# {'nome': 'A4 1.8  Mec.', 'codigo': 69}
# {'nome': 'A4 1.8 Avant Aut.', 'codigo': 70}
# {'nome': 'A4 1.8 Avant Mec.', 'codigo': 71}
# {'nome': 'A4 1.8 Avant Turbo Mec.', 'codigo': 72}
# {'nome': 'A4 1.8 Avant Turbo Tip./ Multitronic', 'codigo': 73}
# {'nome': 'A4 1.8 Tip./ Multitronic Turbo', 'codigo': 74}
# {'nome': 'A4 1.8 Turbo', 'codigo': 75}
# {'nome': 'A4 2.0 16V TFSI 183/180cv Multitronic', 'codigo': 4843}
# {'nome': 'A4 2.0 16V TFSI 200/ 214cv Multitronic', 'codigo': 4182}
# {'nome': 'A4 2.0 16V TFSI Quattro Stronic', 'codigo': 6144}
# {'nome': 'A4 2.0 20V 130cv Multitronic 4p', 'codigo': 76}
# {'nome': 'A4 2.0 Avant 16V TFSI Quattro Stronic', 'codigo': 6145}
# {'nome': 'A4 2.0 Avant Ambie. 2.0 16V TFSi S tron.', 'codigo': 7750}
# {'nome': 'A4 2.0 Avant TFSI 183/180cv Multitroni', 'codigo': 4844}
# {'nome': 'A4 2.0 Avant TFSI 200/214cv Multitron.', 'codigo': 4183}
# {'nome': 'A4 2.4 30V Avant Mec.', 'codigo': 77}
# {'nome': 'A4 2.4 30V Avant Tip./Multitronic', 'codigo': 78}
# {'nome': 'A4 2.4 30V Mec.', 'codigo': 79}
# {'nome': 'A4 2.4 30V Tip./Multitronic', 'codigo': 80}
# {'nome': 'A4 2.4 Avant V6 30V Quattro Mec.', 'codigo': 81}
# {'nome': 'A4 2.4 Avant V6 30V Quattro Tiptronic', 'codigo': 82}
# {'nome': 'A4 2.4 V6 30V Quattro Mec.', 'codigo': 83}
# {'nome': 'A4 2.4 V6 30V Quattro Tiptronic', 'codigo': 84}
# {'nome': 'A4 2.8', 'codigo': 85}
# {'nome': 'A4 2.8 30V  Tiptronic/ Aut.', 'codigo': 86}
# {'nome': 'A4 2.8 30V Mec.', 'codigo': 87}
# {'nome': 'A4 2.8 Avant V6 12V', 'codigo': 88}
# {'nome': 'A4 2.8 Avant V6 30V Mec.', 'codigo': 89}
# {'nome': 'A4 2.8 Avant V6 30V Quattro Mec.', 'codigo': 90}
# {'nome': 'A4 2.8 Avant V6 30V Quattro Tiptronic', 'codigo': 91}
# {'nome': 'A4 2.8 Avant V6 30V Tiptronic', 'codigo': 92}
# {'nome': 'A4 2.8 V6 30V  Quattro Tiptronic', 'codigo': 93}
# {'nome': 'A4 2.8 V6 30V Quattro Mec.', 'codigo': 94}
# {'nome': 'A4 3.0 30V 218cv Multitronic 4p', 'codigo': 95}
# {'nome': 'A4 3.0 30V 218cv Quattro Tiptron./Aut 4p', 'codigo': 96}
# {'nome': 'A4 3.0 Avant 30V 218cv Multitronic 5p', 'codigo': 97}
# {'nome': 'A4 3.0 Avant 30V 218cv Quattro Tiptronic', 'codigo': 98}
# {'nome': 'A4 3.0 Cabriolet 30V 218cv Multitronic', 'codigo': 99}
# {'nome': 'A4 3.2 FSI 24V 255cv Multitronic', 'codigo': 4286}
# {'nome': 'A4 3.2 FSI 24V 269cv Quattro Tiptronic', 'codigo': 4731}
# {'nome': 'A4 3.2 FSI Avant 24V 255cv Multitronic', 'codigo': 4287}
# {'nome': 'A4 3.2 FSI Avant 24V Quattro S Tronic', 'codigo': 4935}
# {'nome': 'A4 3.2 FSI Cabriolet 24V 255cv Multitron', 'codigo': 4288}
# {'nome': 'A4 Ambiente 2.0 TFSI 190cv S tronic', 'codigo': 7717}
# {'nome': 'A4 Ambition 2.0 TFSI Quattro S tronic', 'codigo': 7894}
# {'nome': 'A4 Attraction 2.0 TFSI 190cv S tronic', 'codigo': 7656}
# {'nome': 'A4 Avant Lim. Ed. 2.0 TFSI S tronic', 'codigo': 8228}
# {'nome': 'A4 Avant Prest. Plus 2.0 TFSI S-tronic', 'codigo': 8769}
# {'nome': 'A4 Launch Edition 2.0 TFSI 190cv S troni', 'codigo': 7537}
# {'nome': 'A4 Limited Edition 2.0 TFSI S tronic', 'codigo': 8229}
# {'nome': 'A4 Perfor. Black 2.0 TFSI Quat. S tronic', 'codigo': 9223}
# {'nome': 'A4 Prestige 2.0 TFSI S-tronic', 'codigo': 9894}
# {'nome': 'A4 Prestige Plus 2.0 TFSI 190cv S tronic', 'codigo': 8771}
# {'nome': 'A4 S Line 2.0  TFSI 204cv S Tonic', 'codigo': 9824}
# {'nome': 'A5 3.2 FSI 24V 269cv Multitronic', 'codigo': 4798}
# {'nome': 'A5 3.2 FSI V6 24V 269cv Quattro Tiptroni', 'codigo': 5126}
# {'nome': 'A5 Ambiente Sportb. 2.0 TFSI S tonic', 'codigo': 7999}
# {'nome': 'A5 Ambit. Plus Sport. 2.0 TFSI S tronic', 'codigo': 8000}
# {'nome': 'A5 Ambit. Sport. 2.0 TFSI S tronic', 'codigo': 8001}
# {'nome': 'A5 Attraction Sportb. 2.0 TFSI S tronic', 'codigo': 8002}
# {'nome': 'A5 Cabriolet 2.0 TFSI Quattro Stronic', 'codigo': 6082}
# {'nome': 'A5 Coupê 2.0 TFSI Quattro Stronic', 'codigo': 6083}
# {'nome': 'A5 Sportb. 2.0 16V TFSI Quat. S-tronic', 'codigo': 6084}
# {'nome': 'A5 Sportb. Perf. 2.0 TFSI Quat. S-tronic', 'codigo': 8564}
# {'nome': 'A5 Sportb. Prestige 2.0 16V TFSI S-troni', 'codigo': 8565}
# {'nome': 'A5 Sportb.Perf.B. 2.0 TFSI Quat. S-troni', 'codigo': 8566}
# {'nome': 'A5 Sportb.Prestige Plus 2.0 TFSI S-tronc', 'codigo': 8567}
# {'nome': 'A5 Sportback 1.8 TFSI 170cv Multi.', 'codigo': 7022}
# {'nome': 'A5 Sportback 2.0 16V TFSI 180cv Multi.', 'codigo': 6043}
# {'nome': 'A5 Sportback 2.0 16V TFSI 211cv Multi.', 'codigo': 5234}
# {'nome': 'A5 Sportback S-Line 2.0 TFSI S-tronic', 'codigo': 8772}
# {'nome': 'A6 2.0 TFSI 252cv S tronic 4p', 'codigo': 7254}
# {'nome': 'A6 2.4 30V Mec', 'codigo': 100}
# {'nome': 'A6 2.4 30V Tip./Multitronic', 'codigo': 101}
# {'nome': 'A6 2.4 Avant 30V Mec.', 'codigo': 102}
# {'nome': 'A6 2.4 Avant 30V Tip./ Multitronic', 'codigo': 103}
# {'nome': 'A6 2.4 Avant V6 30V Quattro Mec.', 'codigo': 104}
# {'nome': 'A6 2.4 Avant V6 30V Quattro Tiptronic', 'codigo': 105}
# {'nome': 'A6 2.4 V6 30V Quattro Mec', 'codigo': 106}
# {'nome': 'A6 2.4 V6 30V Quattro Tiptronic', 'codigo': 107}
# {'nome': 'A6 2.7 30V Avant Tiptronic', 'codigo': 108}
# {'nome': 'A6 2.7 30V Mec.', 'codigo': 109}
# {'nome': 'A6 2.7 Avant Quattro Tiptronic', 'codigo': 110}
# {'nome': 'A6 2.7 Quattro Tiptronic', 'codigo': 111}
# {'nome': 'A6 2.8', 'codigo': 112}
# {'nome': 'A6 2.8 30V Mec.', 'codigo': 113}
# {'nome': 'A6 2.8 30V Tiptronic', 'codigo': 114}
# {'nome': 'A6 2.8 Avant', 'codigo': 115}
# {'nome': 'A6 2.8 Avant 30V Mec.', 'codigo': 116}
# {'nome': 'A6 2.8 Avant 30V Tiptronic', 'codigo': 117}
# {'nome': 'A6 2.8 Avant V6 30V Quattro Mec.', 'codigo': 118}
# {'nome': 'A6 2.8 Avant V6 30V Quattro Tiptronic', 'codigo': 119}
# {'nome': 'A6 2.8 V6 30V Quattro Mec.', 'codigo': 120}
# {'nome': 'A6 2.8 V6 30V Quattro Tiptronic', 'codigo': 121}
# {'nome': 'A6 3.0 Avant V6 30V 218cv Multitronic 5p', 'codigo': 122}
# {'nome': 'A6 3.0 Avant. TB FSI V6 Quattro Tip. 5p', 'codigo': 5374}
# {'nome': 'A6 3.0 Avant.TFSI V6 Quattro S tronic 5p', 'codigo': 6413}
# {'nome': 'A6 3.0 TB FSI V6 Quattro Tiptronic', 'codigo': 4958}
# {'nome': 'A6 3.0 TFSI V6 Quattro S tronic 4p', 'codigo': 6414}
# {'nome': 'A6 3.0 V6 30V 218cv Multitronic 4p', 'codigo': 123}
# {'nome': 'A6 3.2 FSI 24V 255cv Multitronic', 'codigo': 4526}
# {'nome': 'A6 4.2 Avant Quattro Tiptronic', 'codigo': 124}
# {'nome': 'A6 4.2 Quattro Tiptronic', 'codigo': 125}
# {'nome': 'A6 Allroad 3.0 TFSI V6 Quattro S tronic', 'codigo': 6462}
# {'nome': 'A6 Perf. Black 3.0 TFSI Quattro S-tronic', 'codigo': 9298}
# {'nome': 'A6 Performance 3.0 TFSI Quattro S.tronic', 'codigo': 8814}
# {'nome': 'A6 Prestige Plus 2.0 TFSI Quattro S-tro.', 'codigo': 9451}
# {'nome': 'A7 SP.b. Perf. Bla. 3.0 TFSI Quat. S-tro', 'codigo': 9319}
# {'nome': 'A7 Sportback 2.0 TFSI S Tronic', 'codigo': 7447}
# {'nome': 'A7 Sportback 3.0 TFSI Quattro S Tronic', 'codigo': 5549}
# {'nome': 'A7 Sportback Perf. 3.0 TFSI S-tron Quat.', 'codigo': 8815}
# {'nome': 'A8 3.0 TFSI 310cv Quattro Tiptronic 4p', 'codigo': 7127}
# {'nome': 'A8 4.0 TFSI Quattro Tiptronic', 'codigo': 6631}
# {'nome': 'A8 4.2 Quattro Tiptronic', 'codigo': 126}
# {'nome': 'A8 4.2 V8 32V Tiptronic', 'codigo': 127}
# {'nome': 'A8 6.0 W12 48V 450cv Quattro Tiptronic', 'codigo': 3928}
# {'nome': 'A8 6.3 W12 48V Quattro Tiptronic', 'codigo': 5717}
# {'nome': 'Allroad 2.7 30V Quattro Turbo Tiptronic', 'codigo': 128}
# {'nome': 'Avant RS2', 'codigo': 129}
# {'nome': 'E-TRON Performa. Black Aut. (Elétrico)', 'codigo': 9077}
# {'nome': 'E-TRON Performace Aut. (Elétrico)', 'codigo': 9078}
# {'nome': 'E-TRON S Sportback Quat. Aut. (Elétrico)', 'codigo': 9605}
# {'nome': 'E-TRON Sportb. Perf.Black Aut.(Elétrico)', 'codigo': 9186}
# {'nome': 'E-TRON Sportback Perf. Aut. (Elétrico)', 'codigo': 9187}
# {'nome': 'Q3 1.4 TFSI/TFSI Flex S-tronic 5p', 'codigo': 7255}
# {'nome': 'Q3 2.0 TFSI Quat. 170/180cv S-tronic 5p', 'codigo': 6044}
# {'nome': 'Q3 2.0 TFSI Quat. 211/220cv S-tronic 5p', 'codigo': 6045}
# {'nome': 'Q3 Black Ed. 1.4 TFSI Flex/Black S-tron.', 'codigo': 8230}
# {'nome': 'Q3 Black S Line 1.4 TFSI S-tronic', 'codigo': 9304}
# {'nome': 'Q3 P. Plus 1.4 TFSI Flex/P.Plus S-tronic', 'codigo': 8569}
# {'nome': 'Q3 Perf. Black 2.0 TFSI Tiptr. Quattro', 'codigo': 9796}
# {'nome': 'Q3 Performance 2.0 TFSI Tiptr. Quattro', 'codigo': 9871}
# {'nome': 'Q3 Prest. 1.4 TFSI Flex/Prest. S-tronic', 'codigo': 8568}
# {'nome': 'Q3 Prestige 2.0 TFSI Tiptr.Quatro ', 'codigo': 10111}
# {'nome': 'Q3 SPB Perf. Black 2.0 TFSI Tipt. Quat.', 'codigo': 9835}
# {'nome': 'Q3 SPB Performance 2.0 TFSI Tipt. Quatt.', 'codigo': 9836}
# {'nome': 'Q5 2.0 16V TFSI 225cv Quattro Tiptronic', 'codigo': 6573}
# {'nome': 'Q5 2.0 16V TFSI Quattro S Tronic', 'codigo': 4936}
# {'nome': 'Q5 2.0 TFSI Quattro S tronic (Blindado)', 'codigo': 8231}
# {'nome': 'Q5 3.0 V6 TFSI 272cv Quattro Tiptronic', 'codigo': 6486}
# {'nome': 'Q5 3.2 FSI V6 Quattro S Tronic', 'codigo': 4959}
# {'nome': 'Q5 Ambiente 2.0 TFSI Quattro S tronic', 'codigo': 8036}
# {'nome': 'Q5 Ambition 2.0 TFSI Quattro S tronic', 'codigo': 8037}
# {'nome': 'Q5 Attraction 2.0 TFSI Quattro S tronic', 'codigo': 8038}
# {'nome': 'Q5 Black 2.0 TFSI Quattro S tronic', 'codigo': 8583}
# {'nome': 'Q5 Perf. Black 2.0 TFSIe S.Tr. Qt (Hib.)', 'codigo': 10045}
# {'nome': 'Q5 Performance 2.0 TFSIe S.Tr. Qt (Hib.)', 'codigo': 10046}
# {'nome': 'Q5 Prestige 2.0 TFSI Quattro S tronic', 'codigo': 8584}
# {'nome': 'Q5 Prestige Plus 2.0 TFSI Quat. S tronic', 'codigo': 8585}
# {'nome': 'Q5 SB P Black. 2.0 TFSIe S.Tr. Qt (Hib.)', 'codigo': 10047}
# {'nome': 'Q5 SB Perf. 2.0 TFSIe S.Tr. Qt (Hib.)', 'codigo': 10048}
# {'nome': 'Q5 S-Line 2.0 TFSI Quattro S-tronic', 'codigo': 8773}
# {'nome': 'Q5 S-Line Black 2.0 TFSI Quat. S-Tronic', 'codigo': 9486}
# {'nome': 'Q5 SPB. S-Line Black 2.0 TFSI Qua.S-Tron', 'codigo': 9526}
# {'nome': 'Q5 Sportback S-Line 2.0 TFSI Quat.S-Tron', 'codigo': 9527}
# {'nome': 'Q7 3.0 V6 TDI Quat.Tip. 5p Die./Perfor.', 'codigo': 7917}
# {'nome': 'Q7 3.0 V6 TFSI  Quat.Tip.5p/ Perf.(Híb.)', 'codigo': 10049}
# {'nome': 'Q7 3.6 V6 284cv Quattro Tiptronic', 'codigo': 4694}
# {'nome': 'Q7 4.2 V8 40V 350cv Quattro Tiptronic', 'codigo': 4184}
# {'nome': 'Q7 Perf. Black 3.0 TFSI Quat.Tip.(Híb.)', 'codigo': 10050}
# {'nome': 'Q7 Perf.Black 3.0 TDI Quat.Tip.5p Dies.', 'codigo': 8658}
# {'nome': 'Q7 S-Line 3.0 V6 TFSI Quattro Tiptronic', 'codigo': 9205}
# {'nome': 'Q8 Perf.Black 3.0 TFSI Quat. S-tr.(Híb.)', 'codigo': 10051}
# {'nome': 'Q8 Perfo. 3.0 TFSI Quattro S-tron.(Híb.)', 'codigo': 10052}
# {'nome': 'R8 4.2 V8 426cv Quattro R-tronic', 'codigo': 5235}
# {'nome': 'R8 5.2 V10 Quattro R-tronic/S-tronic', 'codigo': 5236}
# {'nome': 'R8 GT 5.2 V10 560cv Quattro R-tronic', 'codigo': 5974}
# {'nome': 'R8 Spyder 5.2 Quattro R-tronic/S-tronic', 'codigo': 5550}
# {'nome': 'RS E-TRON GT Quattro Aut. (Elétrico)', 'codigo': 9606}
# {'nome': 'RS Q3 2.5 TFSI Quattro S-tronic 5p', 'codigo': 6865}
# {'nome': 'RS Q3 Sportback 2.5 TFSI Quattro S-tron.', 'codigo': 9292}
# {'nome': 'RS Q8 4.0 Bi-TB V8 FSI Quattro Tiptronic', 'codigo': 9224}
# {'nome': 'RS3 Sedan 2.5 TFSI Quattro S-tronic', 'codigo': 8175}
# {'nome': 'RS3 Sportback 2.5 TFSI Quattro S-tronic', 'codigo': 5922}
# {'nome': 'RS4 2.7 Avant V6 30V BI-TB Quattro 380cv', 'codigo': 130}
# {'nome': 'RS4 2.9 Avant V6 TFSI Quattro Tiptronic', 'codigo': 8628}
# {'nome': 'RS4 4.2 Avant 32V FSI Quattro S-tronic', 'codigo': 6487}
# {'nome': 'RS5 4.2 FSI V8 450cv Quattro S-Tron. 2p', 'codigo': 5410}
# {'nome': 'RS5 Coupê 2.9 V6 TFSI Quattro Tiptronic', 'codigo': 8629}
# {'nome': 'RS5 Sportback 2.9 V6 TFSI Quattro Tip.', 'codigo': 9247}
# {'nome': 'RS6 4.0 Avant TFSI BI-TB Quat.Tip.(Hib.)', 'codigo': 10227}
# {'nome': 'RS6 4.2 450cv BI-TB Quattro Tiptronic 4p', 'codigo': 131}
# {'nome': 'RS6 4.2 Avant  BI-TB Quattro Tiptron. 5p', 'codigo': 132}
# {'nome': 'RS6 5.0 Avant.FSI V10 Bi-TB Quattro Tip.', 'codigo': 5335}
# {'nome': 'RS6 5.0 FSI V10 Bi-TB Quattro Tip.', 'codigo': 5336}
# {'nome': 'RS7 Sportback 4.0 TFSI Quattro Tiptronic', 'codigo': 6883}
# {'nome': 'S Q5 3.0 V6 TFSI 354cv Quattro Tiptronic', 'codigo': 6769}
# {'nome': 'S3 1.8 225cv Turbo Quattro', 'codigo': 133}
# {'nome': 'S3 Sedan 2.0 TFSI Quattro 286cv S-tronic', 'codigo': 6951}
# {'nome': 'S3 Sportback 2.0 TFSI Quattro S Tronic', 'codigo': 5127}
# {'nome': 'S4 2.7 Avant Turbo Quattro', 'codigo': 134}
# {'nome': 'S4 2.7 Turbo Quattro Mec.', 'codigo': 135}
# {'nome': 'S4 3.0 Avant TFSI V6 24V Quattro Stronic', 'codigo': 6085}
# {'nome': 'S4 3.0 TFSI V6 24V Quattro Stronic', 'codigo': 6086}
# {'nome': 'S4 4.2 Avant V8 40V 344cv Quattro Tipt.', 'codigo': 136}
# {'nome': 'S4 4.2 V8 40V 344cv Quattro Tiptronic', 'codigo': 137}
# {'nome': 'S5 Cabriolet 3.0 TFSI Quattro Stronic', 'codigo': 6087}
# {'nome': 'S5 Coupê 3.0 TFSI Quattro Stronic', 'codigo': 6088}
# {'nome': 'S5 Sportback 3.0 TFSI Quattro Stronic', 'codigo': 6089}
# {'nome': 'S6 2.2 20V TB', 'codigo': 138}
# {'nome': 'S6 2.2 Avant 20V TB', 'codigo': 139}
# {'nome': 'S6 4.0 TFSI Quattro S-Tronic 4p', 'codigo': 7302}
# {'nome': 'S6 4.2 Avant V8 40V Quattro Tiptronic', 'codigo': 140}
# {'nome': 'S6 4.2 V8 40V Quattro Mec', 'codigo': 141}
# {'nome': 'S6 4.2 V8 40V Quattro Tiptronic', 'codigo': 142}
# {'nome': 'S6 5.2 Avant FSI V10 435cv Quattro Tiptr', 'codigo': 5186}
# {'nome': 'S6 5.2 FSI V10 435cv Quattro Tiptronic', 'codigo': 5187}
# {'nome': 'S6 Plus 4.2 Avant V8 32V', 'codigo': 143}
# {'nome': 'S6 Plus 4.2 V8 32V', 'codigo': 144}
# {'nome': 'S7 4.0 TFSI 420/450cv Quattro S-tronic', 'codigo': 6632}
# {'nome': 'S8 4.0 TFSI Quattro Tiptronic 4p', 'codigo': 7128}
# {'nome': 'S8 4.2 Mec', 'codigo': 145}
# {'nome': 'S8 4.2 Quattro Mec.', 'codigo': 146}
# {'nome': 'S8 4.2 Quattro Tiptronic', 'codigo': 147}
# {'nome': 'S8 4.2 Tiptronic', 'codigo': 148}
# {'nome': 'TT 1.8 TB 180cv', 'codigo': 149}
# {'nome': 'TT 1.8 TB Quattro 225cv', 'codigo': 150}
# {'nome': 'TT 2.0 16v TFSI S-Tronic', 'codigo': 4330}
# {'nome': 'TT Roadster 1.8 TB Quattro 225cv (Conv.)', 'codigo': 151}
# {'nome': 'TT Roadster 2.0 16v TFSI S-Tronic', 'codigo': 4431}
# {'nome': 'TTRS 2.5 TFSI QUATTRO S Tronic', 'codigo': 6258}
# {'nome': 'TTRS Roadster 2.5 TB FSI Quat. S Tronic', 'codigo': 6259}
# {'nome': 'TTS 2.0 TFSI QUATTRO S Tronic', 'codigo': 5128}
# {'nome': 'TTS Roadster 2.0 TB FSI Quattro S Tronic', 'codigo': 5129}

# %%
# Desenvolvendo um Gerador a partir o Iterador acima
def fipe_generator(modelos):
    for modelo in modelos:
        yield modelo

# %%
for modelo in fipe_generator(carros['modelos']):
    print(modelo)
# Out:
# {'nome': 'AMAROK CD2.0 16V/S CD2.0 16V TDI 4x2 Die', 'codigo': 5585}
# {'nome': 'AMAROK CD2.0 16V/S CD2.0 16V TDI 4x4 Die', 'codigo': 5586}
# {'nome': 'AMAROK Comfor. 3.0 V6 TDI 4x4 Dies. Aut.', 'codigo': 9895}
# {'nome': 'AMAROK Comfor. CD 2.0 TDI 4x4 Dies. Aut.', 'codigo': 8531}
# {'nome': 'AMAROK CS2.0 16V/S2.0 16V TDI 4x2 Diesel', 'codigo': 5748}
# {'nome': 'AMAROK CS2.0 16V/S2.0 16V TDI 4x4 Diesel', 'codigo': 5749}
# {'nome': 'AMAROK Extreme CD 3.0 4x4 TB Dies. Aut.', 'codigo': 8532}
# {'nome': 'AMAROK Hig. Extreme CD 2.0 4x4 Dies. Aut', 'codigo': 7854}
# {'nome': 'AMAROK Hig.ULTIMATE CD 2.0 4x4 Dies. Aut', 'codigo': 7674}
# {'nome': 'AMAROK High.CD 2.0 16V TDI 4x4 Dies. Aut', 'codigo': 5940}
# {'nome': 'AMAROK Highline CD 2.0 16V TDI 4x4 Dies.', 'codigo': 5261}
# {'nome': 'AMAROK Highline CD 3.0 4x4 TB Dies. Aut.', 'codigo': 8183}
# {'nome': 'AMAROK SE CD 2.0 16V TDI 4x4 Diesel', 'codigo': 5476}
# {'nome': 'AMAROK T. Dark nome CD 2.0 4x4 Dies Aut', 'codigo': 7367}
# {'nome': 'AMAROK Trendline CD 2.0 16V TDI 4x4 Dies', 'codigo': 5350}
# {'nome': 'AMAROK Trendline CD 2.0 TDI 4X4 Dies Aut', 'codigo': 6277}
# {'nome': 'Apolo GL 1.8', 'codigo': 2359}
# {'nome': 'Apolo GLS/ Vip 1.8', 'codigo': 2360}
# {'nome': 'Bora 2.0 8v Comfortline Aut.', 'codigo': 2362}
# {'nome': 'Bora 2.0 8v Comfortline Mec.', 'codigo': 2363}
# {'nome': 'Bora 2.0/ 2.0 Flex 8v Aut.', 'codigo': 2361}
# {'nome': 'Bora 2.0/ 2.0 Flex 8v Mec.', 'codigo': 2364}
# {'nome': 'Caravelle 2.4 Diesel', 'codigo': 2365}
# {'nome': 'Corrado 2.0 Turbo', 'codigo': 2366}
# {'nome': 'Corrado G-60 2.8', 'codigo': 2367}
# {'nome': 'CROSSFOX  1.6 T. Flex 16V 5p', 'codigo': 7077}
# {'nome': 'CROSSFOX  I MOTION 1.6 T. Flex 16V 5p', 'codigo': 7078}
# {'nome': 'CROSSFOX 1.6 Mi Total Flex 8V 5p', 'codigo': 2368}
# {'nome': 'CROSSFOX I MOTION 1.6 Mi T. Flex 8V 5p', 'codigo': 5983}
# {'nome': 'Delivery Express Turbo Diesel (E6)', 'codigo': 10368}
# {'nome': 'Delivery Express+ Turbo Diesel', 'codigo': 10137}
# {'nome': 'EOS Cab. 2.0 Turbo FSI Tiptronic', 'codigo': 4857}
# {'nome': 'Eurovan 2.4 Diesel', 'codigo': 2369}
# {'nome': 'Fox 1.0 Mi Total Flex 8V 3p', 'codigo': 5082}
# {'nome': 'Fox 1.0 Mi Total Flex 8V 5p', 'codigo': 5083}
# {'nome': 'Fox 1.6 Mi I MOTION Total Flex 8V 5p', 'codigo': 5084}
# {'nome': 'Fox 1.6 Mi Total Flex 8V 5p', 'codigo': 5085}
# {'nome': 'Fox BLUEMOTION 1.0 Mi Total Flex 12V 3p', 'codigo': 6548}
# {'nome': 'Fox BLUEMOTION 1.0 Mi Total Flex 12V 5p', 'codigo': 6549}
# {'nome': 'Fox BlueMotion 1.6 Mi Total Flex 3p.', 'codigo': 6039}
# {'nome': 'Fox BlueMotion 1.6 Mi Total Flex 5p.', 'codigo': 6040}
# {'nome': 'Fox City 1.0 Mi/ 1.0Mi Total Flex 8V 5p', 'codigo': 2370}
# {'nome': 'Fox City 1.0Mi/ 1.0Mi Total Flex 8V 3p', 'codigo': 2371}
# {'nome': 'Fox Comfortline 1.0 Flex 12V 5p', 'codigo': 7269}
# {'nome': 'Fox Comfortline 1.0 Flex 8V 5p', 'codigo': 6934}
# {'nome': 'Fox Comfortline 1.6 Flex 8V 5p', 'codigo': 6935}
# {'nome': 'Fox Comfortline I Motion 1.6 Flex 8V 5p', 'codigo': 6936}
# {'nome': 'Fox Connect 1.6 Flex 8V 5p', 'codigo': 8112}
# {'nome': 'Fox Connect I Motion 1.6 Flex 8V 5p', 'codigo': 8133}
# {'nome': 'Fox extreme 1.6 Mi Total Flex 8V 5p', 'codigo': 4668}
# {'nome': 'Fox Highline I MOTION 1.6 Flex 16V 5p', 'codigo': 6937}
# {'nome': 'Fox Highline1.6 Flex 16V 5p', 'codigo': 6938}
# {'nome': 'Fox PEPPER 1.6 Flex 16V 5p', 'codigo': 7172}
# {'nome': 'Fox PEPPER I MOTION 1.6 Flex 16V 5p', 'codigo': 7173}
# {'nome': 'Fox Plus 1.0Mi/ 1.0Mi Total Flex 8V 3p', 'codigo': 2372}
# {'nome': 'Fox Plus 1.0Mi/ 1.0Mi Total Flex 8V 4p', 'codigo': 2373}
# {'nome': 'Fox Plus 1.6Mi/ 1.6Mi Total Flex 8V 3p', 'codigo': 2374}
# {'nome': 'Fox Plus 1.6Mi/ 1.6Mi Total Flex 8V 4p', 'codigo': 2375}
# {'nome': 'Fox PRIME/Hghi. IMOTION 1.6 T.Flex 8V 5p', 'codigo': 5087}
# {'nome': 'Fox PRIME/Higli. 1.6 Total Flex 8V 5p', 'codigo': 5086}
# {'nome': 'Fox Rock in Rio 1.6 Mi Total Flex 8V 5p', 'codigo': 5599}
# {'nome': 'Fox Route 1.0 Mi Total Flex 8V 3p', 'codigo': 4349}
# {'nome': 'Fox Route 1.0 Mi Total Flex 8V 5p', 'codigo': 4350}
# {'nome': 'Fox Route 1.6 Mi Total Flex 8V 3p', 'codigo': 4351}
# {'nome': 'Fox Route 1.6 Mi Total Flex 8V 5p', 'codigo': 4352}
# {'nome': 'Fox RUN 1.6 Flex 8V 5p', 'codigo': 7637}
# {'nome': 'Fox SELEÇÃO 1.0 Total Flex 8V 5p', 'codigo': 6667}
# {'nome': 'Fox SELEÇÃO 1.6 Total Flex 8V 5p', 'codigo': 6668}
# {'nome': 'Fox SELEÇÃO IMOTION 1.6 Mi T. Flex 8V 5p', 'codigo': 6784}
# {'nome': 'Fox Sportline/Sports 1.0 Tot.Flex 8V 4p', 'codigo': 2379}
# {'nome': 'Fox Sportline/Sports 1.0/1.0 Tot.Flex 3p', 'codigo': 2376}
# {'nome': 'Fox Sportline/Sports 1.6/1.6 Tot.Flex 3p', 'codigo': 2377}
# {'nome': 'Fox Sportline/Sports 1.6/1.6 Tot.Flex 4p', 'codigo': 2378}
# {'nome': 'Fox SUNRISE 1.0 Mi Total Flex 8V 5p', 'codigo': 4928}
# {'nome': 'Fox TRACK 1.0 Flex 12V 5p', 'codigo': 7410}
# {'nome': 'Fox Trendline 1.0 Flex 12V 5p', 'codigo': 7295}
# {'nome': 'Fox Trendline 1.0 Flex 8V 5p', 'codigo': 6939}
# {'nome': 'Fox Trendline 1.6 Flex 8V 5p', 'codigo': 6940}
# {'nome': 'Fox Xtreme 1.6 Flex 8V 5p', 'codigo': 8113}
# {'nome': 'Fusca', 'codigo': 2380}
# {'nome': 'Fusca 2.0 R-Line TSI 16V Aut.', 'codigo': 7079}
# {'nome': 'Fusca 2.0 TSI 16V Aut.', 'codigo': 6278}
# {'nome': 'Fusca 2.0 TSI 16V Mec.', 'codigo': 6279}
# {'nome': 'Gol (novo) 1.0 Mi Total Flex 8V 2p', 'codigo': 6280}
# {'nome': 'Gol (novo) 1.0 Mi Total Flex 8V 4p', 'codigo': 4689}
# {'nome': 'Gol (novo) 1.6 Mi Total Flex 8V 2p', 'codigo': 6281}
# {'nome': 'Gol (novo) 1.6 Mi Total Flex 8V 4p', 'codigo': 4691}
# {'nome': 'Gol (novo) 1.6 Power/Highi T.Flex 8v 4P', 'codigo': 4690}
# {'nome': 'Gol 1.0 Flex 12V 5p', 'codigo': 8323}
# {'nome': 'Gol 1.0 Mi FUN/ Highway/ Sport 16V  2/4p', 'codigo': 2381}
# {'nome': 'Gol 1.0 Plus 16v 2p', 'codigo': 2382}
# {'nome': 'Gol 1.0 Plus 16v 4p', 'codigo': 2383}
# {'nome': 'Gol 1.0 Plus 8v 2p', 'codigo': 2384}
# {'nome': 'Gol 1.0 Plus 8v 4p', 'codigo': 2385}
# {'nome': 'Gol 1.0 Power 16v 76cv 4p', 'codigo': 2386}
# {'nome': 'Gol 1.0 Total Flex 8V 5p (25 anos)', 'codigo': 5941}
# {'nome': 'Gol 1.0 Trend/ Power 8V 2p', 'codigo': 2387}
# {'nome': 'Gol 1.0 Trend/ Power 8V 4p', 'codigo': 2388}
# {'nome': 'Gol 1.6 I MOTI.Power/Highli T.Flex 8V 4p', 'codigo': 5114}
# {'nome': 'Gol 1.6 Mi I MOTION Total Flex 8V 3p', 'codigo': 6454}
# {'nome': 'Gol 1.6 Mi Plus Total Flex 8V 2p', 'codigo': 2389}
# {'nome': 'Gol 1.6 Mi Plus Total Flex 8V 4p', 'codigo': 2390}
# {'nome': 'Gol 1.6 Mi Power Total Flex 8V 4p', 'codigo': 2391}
# {'nome': 'Gol 1.6 Mi Rallye I MOTION T. Flex 8V 4p', 'codigo': 5404}
# {'nome': 'Gol 1.6 Mi Rallye Total Flex 8V 4p', 'codigo': 2392}
# {'nome': 'Gol 1.6 Mi/ 1.6i 2p', 'codigo': 2393}
# {'nome': 'Gol 1.6 Mi/ Power 1.6 Mi 4p', 'codigo': 2394}
# {'nome': 'Gol 1.6 MSI Flex 16V 5p Aut.', 'codigo': 8463}
# {'nome': 'Gol 1.6 MSI Flex 8V 5p', 'codigo': 8324}
# {'nome': 'Gol 1.8 Mi', 'codigo': 2395}
# {'nome': 'Gol 1.8 Mi 4p', 'codigo': 2396}
# {'nome': 'Gol 1.8 Mi Power Total Flex 8V 4p', 'codigo': 2397}
# {'nome': 'Gol 1.8 Mi Rallye Total Flex 8V 4p', 'codigo': 2398}
# {'nome': 'Gol 1000 (modelo antigo)', 'codigo': 2399}
# {'nome': 'Gol 1000 Mi 16V 2p Turbo', 'codigo': 2400}
# {'nome': 'Gol 1000 Mi 16V 4p Turbo', 'codigo': 2401}
# {'nome': 'Gol 1000 Mi 16V/ Ouro  2p', 'codigo': 2402}
# {'nome': 'Gol 1000 Mi 16V/ Ouro 4p', 'codigo': 2403}
# {'nome': 'Gol 1000 Mi 2p  / 1000i', 'codigo': 2404}
# {'nome': 'Gol 1000 Mi 4p', 'codigo': 2405}
# {'nome': 'Gol 1000 Mi Plus 16V 2p e 4p', 'codigo': 2406}
# {'nome': 'Gol 1000 Mi Plus 8v 2p e 4p', 'codigo': 2407}
# {'nome': 'Gol 1000i Plus 2p', 'codigo': 2408}
# {'nome': 'Gol 2.0 Mi 2p', 'codigo': 2409}
# {'nome': 'Gol 2.0 Mi 4p', 'codigo': 2410}
# {'nome': 'Gol BLACK 1.0 Mi Total Flex 8V 4p', 'codigo': 5750}
# {'nome': 'Gol City (Trend) 1.0 Mi Total Flex 8V 2p', 'codigo': 2413}
# {'nome': 'Gol City (Trend) 1.6 Mi T. Flex 8V 2p', 'codigo': 3832}
# {'nome': 'Gol City (Trend) 1.6 Mi T.Flex 8V 4p', 'codigo': 2417}
# {'nome': 'Gol City (Trend)/Titan 1.0 T. Flex 8V 4p', 'codigo': 2414}
# {'nome': 'Gol City 1.0 Mi 8V 2p', 'codigo': 2411}
# {'nome': 'Gol City 1.0 Mi 8V 4p', 'codigo': 2412}
# {'nome': 'Gol City 1.0 Total Flex 12V 2p', 'codigo': 9098}
# {'nome': 'Gol City 1.0 Total Flex 12V 4P', 'codigo': 8840}
# {'nome': 'Gol City 1.6 Mi 8V 2p', 'codigo': 2415}
# {'nome': 'Gol City 1.6 Mi 8V 4p', 'codigo': 2416}
# {'nome': 'Gol CL 1.6 Mi 2p e 4p', 'codigo': 2418}
# {'nome': 'Gol CL 1.8 Mi 2p e 4p', 'codigo': 2419}
# {'nome': 'Gol CLi / CL 1.8', 'codigo': 2420}
# {'nome': 'Gol CLi / CL/ Copa/ Stones 1.6', 'codigo': 2421}
# {'nome': 'Gol Comfort. I MOTION 1.6 T. Flex 8V 3p', 'codigo': 6791}
# {'nome': 'Gol Comfort. I MOTION 1.6 T. Flex 8V 5p', 'codigo': 6792}
# {'nome': 'Gol Comfortline 1.0 T. Flex 12V 5p', 'codigo': 7521}
# {'nome': 'Gol Comfortline 1.0 T. Flex 8V 3p', 'codigo': 6787}
# {'nome': 'Gol Comfortline 1.0 T. Flex 8V 5p', 'codigo': 6788}
# {'nome': 'Gol Comfortline 1.6 T. Flex 8V 3p', 'codigo': 6789}
# {'nome': 'Gol Comfortline 1.6 T. Flex 8V 5p', 'codigo': 6790}
# {'nome': 'Gol COPA 1.0 Mi Total Flex 8V 4p', 'codigo': 3958}
# {'nome': 'Gol COPA 1.6 Mi Total Flex 8V 4p', 'codigo': 3959}
# {'nome': 'Gol ECOMOTION  1.0 Mi Total Flex 8V 4p', 'codigo': 5218}
# {'nome': 'Gol ECOMOTION 1.0 Mi Total Flex 8V 2p', 'codigo': 5219}
# {'nome': 'Gol Furgao 1.0 mi', 'codigo': 2422}
# {'nome': 'Gol Furgão 1.6 Mi/ 1.6i/ 1.6', 'codigo': 2423}
# {'nome': 'Gol GL 1.6 Mi/Star 1.6 e 1.8/Atlanta 1.6', 'codigo': 2424}
# {'nome': 'Gol GL 1.8 Mi 2p e 4p', 'codigo': 2425}
# {'nome': 'Gol GLi / GL/ Atlanta 1.8', 'codigo': 2426}
# {'nome': 'Gol GLS 2.0 Mi', 'codigo': 2427}
# {'nome': 'Gol GT/GTS 1.8', 'codigo': 2428}
# {'nome': 'Gol GTi 2.0', 'codigo': 2429}
# {'nome': 'Gol GTi 2000 16V', 'codigo': 2430}
# {'nome': 'Gol I MOTION 1.6 Mi Total Flex 8V 4p', 'codigo': 5113}
# {'nome': 'Gol L 1.3/ L/ LS/ C/ S/ BX/ Plus 1.6', 'codigo': 2431}
# {'nome': 'Gol Last Edition 1.0 Flex 12V 5p', 'codigo': 10166}
# {'nome': 'Gol Plus 1.0 Mi Total Flex 2p', 'codigo': 3833}
# {'nome': 'Gol Plus 1.0 Mi Total Flex 4p', 'codigo': 3834}
# {'nome': 'Gol Rallye 1.6 T. Flex 16V 5p', 'codigo': 6795}
# {'nome': 'Gol Rallye I MOTION 1.6 T. Flex 16V 5p', 'codigo': 6793}
# {'nome': 'Gol Rock in Rio 1.0 Mi Total Flex 8V 5p', 'codigo': 5600}
# {'nome': 'Gol SELEÇÃO 1.0 Mi Total Flex 8V 5p', 'codigo': 5220}
# {'nome': 'Gol SELEÇÃO 1.6 I MOTION T.Flex 8V 5p', 'codigo': 6669}
# {'nome': 'Gol SELEÇÃO 1.6 Total Flex 8V 5p', 'codigo': 6670}
# {'nome': 'Gol Special 1.0 Mi 4p', 'codigo': 2432}
# {'nome': 'Gol Special 1.0 Total Flex 8V 3p', 'codigo': 7049}
# {'nome': 'Gol Special 1.0 Total Flex 8V 5p', 'codigo': 7050}
# {'nome': 'Gol Special 1.6 Mi 8V 99cv 2p', 'codigo': 2433}
# {'nome': 'Gol Special/ Special Xtreme 1.0 Mi 2p', 'codigo': 2434}
# {'nome': 'Gol TECH 1.0 Mi Total Flex 8V 2p', 'codigo': 4092}
# {'nome': 'Gol TECH 1.0 Mi Total Flex 8V 4p', 'codigo': 4093}
# {'nome': 'Gol TRACK 1.0 Mi Total Flex 8V 4p', 'codigo': 6472}
# {'nome': 'Gol TRACK 1.0 Total Flex 12V 5p', 'codigo': 7817}
# {'nome': 'Gol Trendline 1.0 T.Flex 12V 3p', 'codigo': 7638}
# {'nome': 'Gol Trendline 1.0 T.Flex 12V 5p', 'codigo': 7522}
# {'nome': 'Gol Trendline 1.0 T.Flex 8V 3p', 'codigo': 6785}
# {'nome': 'Gol Trendline 1.0 T.Flex 8V 5p', 'codigo': 6786}
# {'nome': 'Gol Trendline 1.6 T.Flex 8V 3p', 'codigo': 6977}
# {'nome': 'Gol Trendline 1.6 T.Flex 8V 5p', 'codigo': 6796}
# {'nome': 'Gol Trendline I Motion 1.6 T. Flex 8V 3p', 'codigo': 6976}
# {'nome': 'Gol Trendline I MOTION 1.6 T. Flex 8V 5p', 'codigo': 6794}
# {'nome': 'Gol TSi 1.8/ 1.8Mi', 'codigo': 2435}
# {'nome': 'Gol TSi 2000 2p e 4p', 'codigo': 2436}
# {'nome': 'Golf  BLACK EDITON 2.0 Mi T. Flex 8V Tip', 'codigo': 5115}
# {'nome': 'Golf  TECH 1.6 Mi Total Flex 8V 4p', 'codigo': 4669}
# {'nome': 'Golf 1.6 Mi Total Flex 8V 4p', 'codigo': 4006}
# {'nome': 'Golf 1.6 Mi Trip/ Sport 101cv 8V', 'codigo': 2437}
# {'nome': 'Golf 1.6Mi/ 1.6Mi Gener./Black & Silver', 'codigo': 2438}
# {'nome': 'Golf 1.8 Mi Sport 150cv Turbo Mec/Aut.', 'codigo': 2439}
# {'nome': 'Golf 2.0/ 2.0 Mi Flex Aut/Tiptronic.', 'codigo': 2440}
# {'nome': 'Golf 2.0/ 2.0 Mi Flex Comfortline Aut.', 'codigo': 2442}
# {'nome': 'Golf 2.0/ 2.0 Mi Flex Comfortline/ Sport', 'codigo': 2443}
# {'nome': 'Golf 2.0/2.0 T. Flex Mec.(Black & Silv)', 'codigo': 2441}
# {'nome': 'Golf Comfort. 200 TSI 1.0 Flex 12V Aut.', 'codigo': 8369}
# {'nome': 'Golf Comfortline 1.0 TSI Total Flex Mec.', 'codigo': 7781}
# {'nome': 'Golf Comfortline 1.4 TSI 140cv Aut.', 'codigo': 6797}
# {'nome': 'Golf Comfortline 1.4 TSI 140cv Mec.', 'codigo': 6798}
# {'nome': 'Golf Comfortline 1.6 MSI Total Flex Aut.', 'codigo': 7460}
# {'nome': 'Golf Comfortline 1.6 MSI Total Flex Mec.', 'codigo': 7461}
# {'nome': 'Golf Flash 1.6 Mi/1.6 Mi Tot. Flex 8V 4p', 'codigo': 3914}
# {'nome': 'Golf GL 1.8/ 2.0i 4p', 'codigo': 2444}
# {'nome': 'Golf GLX 2.0 4p', 'codigo': 2445}
# {'nome': 'Golf GT 2.0 Mi T. Flex 8V 4p Tiptronic', 'codigo': 4835}
# {'nome': 'Golf GT 2.0 Mi Total Flex 8V 4p', 'codigo': 4703}
# {'nome': 'Golf GTE TSI 1.4 16V Híbrido Aut.', 'codigo': 8943}
# {'nome': 'Golf GTi 1.8 Mi 180/193cv Turbo 4p Mec.', 'codigo': 2446}
# {'nome': 'Golf GTi 1.8 Mi 180/193cv Turbo 4p Tip.', 'codigo': 2447}
# {'nome': 'Golf GTi 1.8 Mi 20V 2p Turbo Mec.', 'codigo': 2448}
# {'nome': 'Golf GTi 1.8 Mi 20V Turbo 2p Aut.', 'codigo': 2449}
# {'nome': 'Golf GTi 1.8 Mi 20V Turbo 4p Aut.', 'codigo': 2450}
# {'nome': 'Golf GTi 1.8 Mi 20V Turbo 4p Mec.', 'codigo': 2451}
# {'nome': 'Golf GTI 1.8 Turbo', 'codigo': 2452}
# {'nome': 'Golf GTi 2.0', 'codigo': 2453}
# {'nome': 'Golf GTi 2.0 TSI 220cv Aut.', 'codigo': 6600}
# {'nome': 'Golf GTi 350 TSI 2.0 230cv 16V Aut.', 'codigo': 8370}
# {'nome': 'Golf GTi Cabrio 2.0 Mi', 'codigo': 2454}
# {'nome': 'Golf GTI VR6/ Golf 2.8 VR6', 'codigo': 2455}
# {'nome': 'Golf Highline 1.4 TSI 140cv Aut.', 'codigo': 6601}
# {'nome': 'Golf Highline 1.4 TSI 140cv Mec.', 'codigo': 6602}
# {'nome': 'Golf Highline 1.4 TSI Total Flex Aut.', 'codigo': 7462}
# {'nome': 'Golf Highline 1.4 TSI Total Flex Mec.', 'codigo': 7463}
# {'nome': 'Golf Highline 250 TSI 1.4 Flex 16V Aut.', 'codigo': 8371}
# {'nome': 'Golf SILVER EDIT. 2.0 Mi T.Flex 8v Mec.', 'codigo': 5007}
# {'nome': 'Golf SILVER EDIT. 2.0 Mi T.Flex 8V Tip.', 'codigo': 5008}
# {'nome': 'Golf Sportline 1.6 Mi Total Flex 8V 4p', 'codigo': 4312}
# {'nome': 'Golf Sportline 2.0 Mi Total F. 8V Tip.', 'codigo': 5221}
# {'nome': 'Golf Variant Comf. 250 1.4 TSI Flex Aut.', 'codigo': 8372}
# {'nome': 'Golf Variant Comfort. 1.4 TSI T.Flex Aut', 'codigo': 7782}
# {'nome': 'Golf Variant Comfortline 1.4 TSI  Aut.', 'codigo': 7270}
# {'nome': 'Golf Variant Comfortline 1.4 TSI Mec.', 'codigo': 7464}
# {'nome': 'Golf Variant High. 250 1.4 TSI Flex Aut.', 'codigo': 8373}
# {'nome': 'Golf Variant Highli. 1.4 TSI T.Flex Aut', 'codigo': 7748}
# {'nome': 'Golf Variant Highline 1.4 TSI Aut.', 'codigo': 7271}
# {'nome': 'Grand Saveiro Xtreme/Street  1.6/1.8/2.0', 'codigo': 2456}
# {'nome': 'JETTA  GLX III 2.8 VR6', 'codigo': 2457}
# {'nome': 'JETTA 2.5 20V 150/170cv Tiptronic', 'codigo': 4147}
# {'nome': 'JETTA 250 TSI 1.4 flex 16v Aut.', 'codigo': 8581}
# {'nome': 'JETTA Comfort. 250 TSI 1.4 Flex 16v Aut.', 'codigo': 8487}
# {'nome': 'JETTA Comfortline  2.0 T.Flex 8V 4p Mec.', 'codigo': 5512}
# {'nome': 'JETTA Comfortline 1.4 TSI 16V 4p Aut.', 'codigo': 7493}
# {'nome': 'JETTA Comfortline 2.0 T.Flex 8V 4p Tipt.', 'codigo': 5513}
# {'nome': 'JETTA GLI 350 TSI 2.0 16V 4p Aut.', 'codigo': 8717}
# {'nome': 'JETTA Highline 2.0 TSI 16V 4p Tiptronic', 'codigo': 5514}
# {'nome': 'JETTA R-Line 250 TSI 1.4 Flex 16V Aut.', 'codigo': 8488}
# {'nome': 'JETTA Trendline 1.4 TSI 16V 4p  Aut.', 'codigo': 7494}
# {'nome': 'JETTA Trendline 1.4 TSI 16V 4p Mec.', 'codigo': 7495}
# {'nome': 'JETTA Trendline 2.0 T.Flex 8V 4p Tip.', 'codigo': 7216}
# {'nome': 'JETTA Variant 2.5 20V 170cv Tiptronic', 'codigo': 4649}
# {'nome': 'Kombi Carat', 'codigo': 2458}
# {'nome': 'Kombi Escolar 1.6 MPi', 'codigo': 2459}
# {'nome': 'Kombi Escolar/50 anos 1.4 Mi Total Flex', 'codigo': 3980}
# {'nome': 'Kombi Furgão', 'codigo': 2460}
# {'nome': 'Kombi Furgão 1.4 Mi Total Flex 8V', 'codigo': 3915}
# {'nome': 'Kombi Furgão Diesel', 'codigo': 2461}
# {'nome': 'Kombi LAST EDITION 56 1.4 Mi Total Flex', 'codigo': 6618}
# {'nome': 'Kombi Lotação 1.4 Mi Total Flex 8V', 'codigo': 3981}
# {'nome': 'Kombi Lotação 1.6 MPi', 'codigo': 2462}
# {'nome': 'Kombi Pick-Up', 'codigo': 2463}
# {'nome': 'Kombi Pick-Up Diesel', 'codigo': 2464}
# {'nome': 'Kombi Standard 1.4 Mi Total Flex 8V', 'codigo': 3916}
# {'nome': 'Kombi Standard/ Luxo/ Série Prata', 'codigo': 2465}
# {'nome': 'Logus 1.6 / CLi / CL/ GL', 'codigo': 2466}
# {'nome': 'Logus 1.8 / CLi / CL', 'codigo': 2467}
# {'nome': 'Logus GLi / GL 1.8', 'codigo': 2468}
# {'nome': 'Logus GLS 1.8', 'codigo': 2469}
# {'nome': 'Logus GLSi / GLS 2000', 'codigo': 2470}
# {'nome': 'Logus Wolfsburg Edition 2000i', 'codigo': 2471}
# {'nome': 'New Beetle 2.0 Mi Mec./Aut.', 'codigo': 2472}
# {'nome': 'Nivus Comfortline 1.0 200 TSI Flex Aut.', 'codigo': 9150}
# {'nome': 'Nivus Highline 1.0 200 TSI Flex Aut.', 'codigo': 9151}
# {'nome': 'Nivus Launching Ed. 1.0 200 TSI Flex Aut', 'codigo': 9152}
# {'nome': 'Parati 1.0 Mi FUN/ SunSet 16V 4p', 'codigo': 2473}
# {'nome': 'Parati 1.0 Mi Plus 16v 4p', 'codigo': 2474}
# {'nome': 'Parati 1.0 Mi Summer 16v 4p', 'codigo': 2475}
# {'nome': 'Parati 1.0 Mi Tour 16V 76cv 4p', 'codigo': 2476}
# {'nome': 'Parati 1.6 Mi Plus Total Flex  8V 4p', 'codigo': 2500}
# {'nome': 'Parati 1.6 Mi/ 1.6 Mi City', 'codigo': 2477}
# {'nome': 'Parati 1.6Mi/1.6Mi City/T.Field T.Flex', 'codigo': 2478}
# {'nome': 'Parati 1.8 Mi City Total Flex 8V 4p', 'codigo': 2479}
# {'nome': 'Parati 1.8 Mi CROSSOVER Total Flex 8V 4p', 'codigo': 2480}
# {'nome': 'Parati 1.8 Mi Plus Total Flex 8V 4p', 'codigo': 3804}
# {'nome': 'Parati 1.8 Mi T. Field Total Flex 8V 4p', 'codigo': 2481}
# {'nome': 'Parati 1.8 Mi Tour 8V 99cv 4p', 'codigo': 2482}
# {'nome': 'Parati 1.8 Mi/ 1.8 Mi Plus', 'codigo': 2483}
# {'nome': 'Parati 1000 Mi 16V 2p e 4p', 'codigo': 2484}
# {'nome': 'Parati 1000 Mi 16V 4p Turbo', 'codigo': 2485}
# {'nome': 'Parati 2.0 Mi Tour 8V 112cv 4p', 'codigo': 2486}
# {'nome': 'Parati 2.0 Mi/ 2.0 Mi Track & Field', 'codigo': 2487}
# {'nome': 'Parati C 1.6/ CL 1.6 Mi 2p e 4p', 'codigo': 2488}
# {'nome': 'Parati CL 1.8 Mi 2p e 4p', 'codigo': 2489}
# {'nome': 'Parati CLi / CL/ Atlanta 1.6', 'codigo': 2490}
# {'nome': 'Parati CLi / CL/ Atlanta 1.8', 'codigo': 2491}
# {'nome': 'Parati COMFORTLINE 1.6 Mi Tot.Flex 8V 4p', 'codigo': 3960}
# {'nome': 'Parati COMFORTLINE 1.8 Mi Tot.Flex 8V 4p', 'codigo': 3805}
# {'nome': 'Parati CROSSOVER 2.0 8V/ 1.0 16V TB 4p', 'codigo': 2492}
# {'nome': 'Parati Evidence 1.8 8V/ 1.0 16V TB 4p', 'codigo': 2493}
# {'nome': 'Parati GL 1.6 Mi/ 1.6/ GLS/ Club 1.6', 'codigo': 2494}
# {'nome': 'Parati GL 1.8 Mi/ Club 1.8 Mi 2p e 4p', 'codigo': 2495}
# {'nome': 'Parati GLi / GL 1.8', 'codigo': 2496}
# {'nome': 'Parati GLS 2.0 Mi 2/4p', 'codigo': 2497}
# {'nome': 'Parati GLSi 2.0 / GLS/ Surf 1.8', 'codigo': 2498}
# {'nome': 'Parati GTi 2.0 Mi 16V', 'codigo': 2499}
# {'nome': 'Parati Plus/ LS/ S', 'codigo': 2501}
# {'nome': 'Parati SURF 1.6 Mi Total Flex', 'codigo': 4521}
# {'nome': 'Parati SURF 1.8 Mi Total Flex', 'codigo': 4522}
# {'nome': 'Parati TITAN 1.6 Mi Total Flex 8V 4p', 'codigo': 4908}
# {'nome': 'Parati Utility 1.8 8V/ 1.0 Turbo 16V', 'codigo': 2502}
# {'nome': 'Passat  L/LS/LSe/GL/GLS/TS/Fla/Vill/Plus', 'codigo': 2503}
# {'nome': 'Passat 1.8 Aut.', 'codigo': 2504}
# {'nome': 'Passat 1.8 Mec.', 'codigo': 2505}
# {'nome': 'Passat 1.8 Tiptronic', 'codigo': 2506}
# {'nome': 'Passat 2.0', 'codigo': 2507}
# {'nome': 'Passat 2.0 FSI Tiptronic', 'codigo': 3806}
# {'nome': 'Passat 2.8 V6 Mec.', 'codigo': 2508}
# {'nome': 'Passat 2.8 V6 Protect Tiptronic', 'codigo': 2509}
# {'nome': 'Passat 2.8 V6 Tiptronic', 'codigo': 2510}
# {'nome': 'Passat 3.2 V6 FSI 24V 250cv Tip.', 'codigo': 4322}
# {'nome': 'Passat CC 2.0 TSI 211cv Tiptronic', 'codigo': 6896}
# {'nome': 'Passat CC 3.6 V6 FSI 300cv Tiptronic', 'codigo': 4929}
# {'nome': 'Passat Comfortline 2.0 TSI 220cv Tip.', 'codigo': 7465}
# {'nome': 'Passat Highline 2.0 TSI 220cv Tip.', 'codigo': 7466}
# {'nome': 'Passat Pointer GTS', 'codigo': 2511}
# {'nome': 'Passat R-Line TB 2.0 TSI Tiptronic 4p', 'codigo': 7051}
# {'nome': 'Passat TB 2.0 FSI/TSI 211cv Tiptronic 4p', 'codigo': 4148}
# {'nome': 'Passat Turbo 1.8 Mec.', 'codigo': 2512}
# {'nome': 'Passat Turbo 1.8 Tiptronic', 'codigo': 2513}
# {'nome': 'Passat Variant  2.0 FSI 150cv Tiptron.5p', 'codigo': 3917}
# {'nome': 'Passat Variant 1.8 Aut.', 'codigo': 2514}
# {'nome': 'Passat Variant 1.8 Mec.', 'codigo': 2515}
# {'nome': 'Passat Variant 2.0', 'codigo': 2516}
# {'nome': 'Passat Variant 2.8 V6', 'codigo': 2517}
# {'nome': 'Passat Variant 2.8 V6 Tiptronic', 'codigo': 2518}
# {'nome': 'Passat Variant 3.2 V6 FSI 24V 250cv Tip.', 'codigo': 4323}
# {'nome': 'Passat Variant R-Line TB 2.0 TSI Tip. 5p', 'codigo': 7320}
# {'nome': 'Passat Variant Turbo 1.8', 'codigo': 2519}
# {'nome': 'Passat Variant Turbo 1.8 Tiptronic', 'codigo': 2520}
# {'nome': 'Passat Variant Turbo 2.0 FSI Tiptron. 5p', 'codigo': 4149}
# {'nome': 'Passat Variant VR6 2.8', 'codigo': 2521}
# {'nome': 'Passat VR6 2.8', 'codigo': 2522}
# {'nome': 'Pointer 1.8 / CLi', 'codigo': 2523}
# {'nome': 'Pointer GLi 1.8', 'codigo': 2524}
# {'nome': 'Pointer GLi 2.0', 'codigo': 2525}
# {'nome': 'Pointer GTi 2.0', 'codigo': 2526}
# {'nome': 'Polo 1.0 Flex 12V 5p', 'codigo': 8070}
# {'nome': 'Polo 1.0 Mi 79cv 16V 5p', 'codigo': 2527}
# {'nome': 'Polo 1.0 MPI Flex 12V 5p', 'codigo': 10107}
# {'nome': 'Polo 1.0 TSI Flex 12V 5p', 'codigo': 10108}
# {'nome': 'Polo 1.6 E-Flex 8V 5p', 'codigo': 4930}
# {'nome': 'Polo 1.6 Mi/ S.Ouro 1.6Mi 101cv 8V 5p', 'codigo': 2528}
# {'nome': 'Polo 1.6 Mi/S.Ouro 1.6 Mi Tot.Flex 8V 5p', 'codigo': 2529}
# {'nome': 'Polo 1.6 MSI Flex 16V 5p', 'codigo': 8067}
# {'nome': 'Polo 1.6 MSI Total Flex 16V 5p Aut.', 'codigo': 8426}
# {'nome': 'Polo 2.0 Mi 116cv 8V 5p', 'codigo': 2530}
# {'nome': 'Polo BLUEMOTION 1.6 Total Flex 8V 5p', 'codigo': 4909}
# {'nome': 'Polo Classic 1.0 Mi 16v  65cv 4p', 'codigo': 2531}
# {'nome': 'Polo Classic/ Special 1.8 Mi', 'codigo': 2532}
# {'nome': 'Polo Comfort. 200 TSI 1.0 Flex 12V Aut.', 'codigo': 8068}
# {'nome': 'Polo Comfortline TSI 1.0 Flex 12V Aut.', 'codigo': 10109}
# {'nome': 'Polo GT 2.0 Mi Total Flex 8V 5p', 'codigo': 4797}
# {'nome': 'Polo GTI 1.8 Mi 150cv 20V Turbo 3p', 'codigo': 4300}
# {'nome': 'Polo GTS 1.4 TSI 16V Flex', 'codigo': 8996}
# {'nome': 'Polo Highline 200 TSI 1.0 Flex 12V Aut.', 'codigo': 8069}
# {'nome': 'Polo Highline TSI 1.0 Flex 12V Aut.', 'codigo': 10110}
# {'nome': 'Polo I MOTION 1.6 Total Flex  5p', 'codigo': 4989}
# {'nome': 'Polo Next 1.6 Mi 101cv 8V 5p', 'codigo': 2533}
# {'nome': 'Polo Sed. COMFORT. 1.6 Mi Tot. Flex 8v', 'codigo': 3982}
# {'nome': 'Polo Sed./Sed. COMF. 2.0/2.0 Flex 8V 4p', 'codigo': 2536}
# {'nome': 'Polo Sed.COMFORT. I MOTION 1.6 T.Flex 4p', 'codigo': 4990}
# {'nome': 'Polo Sedan 1.6 Mi 101cv 8V 4p', 'codigo': 2534}
# {'nome': 'Polo Sedan 1.6 Mi Total Flex 8V 4p', 'codigo': 2535}
# {'nome': 'Polo Sedan Evidence 1.6 Mi T.Flex 8v 4p', 'codigo': 2537}
# {'nome': 'Polo Sedan I MOTION  1.6 Total Flex  4p', 'codigo': 4991}
# {'nome': 'Polo Sense 200 TSI 1.0 Flex 12V Aut', 'codigo': 9558}
# {'nome': 'Polo SPORTLINE 1.6 Mi Total Flex 8V 5p', 'codigo': 3983}
# {'nome': 'Polo Sportline 2.0 Mi Total Flex 8V 5p', 'codigo': 5654}
# {'nome': 'Polo SPORTLINE I MOTION 1.6 T.Flex 5p', 'codigo': 4992}
# {'nome': 'Polo Track 1.0 Flex 12V 5p', 'codigo': 10176}
# {'nome': 'Quantum 1.8 Mi/ 1.8i', 'codigo': 2538}
# {'nome': 'Quantum 2.0 Mi', 'codigo': 2539}
# {'nome': 'Quantum CLi / CL / C/ CS/ CD/ CG 1.8/2.0', 'codigo': 2540}
# {'nome': 'Quantum Evidence 2.0 Mi', 'codigo': 2541}
# {'nome': 'Quantum Exclusive 2.0 Mi', 'codigo': 2542}
# {'nome': 'Quantum GLi / GL 1.8/ 2.0', 'codigo': 2543}
# {'nome': 'Quantum GLSi / GLS 1.8/Sport/ Family 2.0', 'codigo': 2544}
# {'nome': 'Santana 1.8 Mi', 'codigo': 2545}
# {'nome': 'Santana 2.0 Mi 2p e 4p', 'codigo': 2546}
# {'nome': 'Santana CLi /CL /C 1.8/2.0 /SU 2.0 2p/4p', 'codigo': 2547}
# {'nome': 'Santana COMFORTLINE 1.8 Mi 8V 4p', 'codigo': 3961}
# {'nome': 'Santana CS/CD/CG', 'codigo': 2548}
# {'nome': 'Santana Evidenc 2.0 MI', 'codigo': 2549}
# {'nome': 'Santana Exclusiv 2.0 Mi/ Executivo 2.0i', 'codigo': 2550}
# {'nome': 'Santana GLi / GL/ Sport 1.8/ 2.0', 'codigo': 2551}
# {'nome': 'Santana GLSi / GLS 1.8/ 2.0', 'codigo': 2552}
# {'nome': 'Saveiro 1.6 Mi Total Flex 8V CE', 'codigo': 5009}
# {'nome': 'Saveiro 1.6 Mi/ 1.6 Mi Total Flex 8V', 'codigo': 2553}
# {'nome': 'Saveiro 1.6 Mi/ 1.6Mi City Total Flex 8V', 'codigo': 2554}
# {'nome': 'Saveiro 1.8 Mi', 'codigo': 2555}
# {'nome': 'Saveiro 2.0 Mi', 'codigo': 2556}
# {'nome': 'Saveiro City 1.8 Mi Total Flex 8V', 'codigo': 2557}
# {'nome': 'Saveiro CL 1.6 Mi / CL/ C 1.6', 'codigo': 2558}
# {'nome': 'Saveiro CL/ Summer 1.8 Mi e 1.8', 'codigo': 2559}
# {'nome': 'Saveiro CROSS 1.6 Mi Total Flex 8V CE', 'codigo': 5195}
# {'nome': 'Saveiro CROSS 1.6 T. Flex 16V CE', 'codigo': 6801}
# {'nome': 'Saveiro CROSS 1.6 T.Flex 16V CD', 'codigo': 6941}
# {'nome': 'Saveiro CROSSOVER 1.6 Mi Total Flex 8V', 'codigo': 3962}
# {'nome': 'Saveiro CROSSOVER 1.8 Mi 8V', 'codigo': 2560}
# {'nome': 'Saveiro CROSSOVER 1.8 Mi Total Flex 8V', 'codigo': 2561}
# {'nome': 'Saveiro Diesel (todas)', 'codigo': 2562}
# {'nome': 'Saveiro FUN 1.8 99cv/ City e S.Surf  1.6', 'codigo': 2563}
# {'nome': 'Saveiro GL 1.8Mi e 1.6/GL/LS/S/ Sunset', 'codigo': 2564}
# {'nome': 'Saveiro Highline 1.6 T. Flex 8V CD', 'codigo': 6942}
# {'nome': 'Saveiro Pepper 1.6 Flex 8V CD', 'codigo': 8026}
# {'nome': 'Saveiro Pepper 1.6 Flex 8V CE', 'codigo': 8027}
# {'nome': 'Saveiro Robust 1.6 Total Flex 16V ', 'codigo': 10141}
# {'nome': 'Saveiro Robust 1.6 Total Flex 16V CD', 'codigo': 10142}
# {'nome': 'Saveiro Robust 1.6 Total Flex 8V', 'codigo': 7566}
# {'nome': 'Saveiro Robust 1.6 Total Flex 8V CD', 'codigo': 7960}
# {'nome': 'Saveiro Rock in Rio 1.6 Total Flex 8V CD', 'codigo': 7272}
# {'nome': 'Saveiro SPORTLINE 1.6 Mi Total Flex 8V', 'codigo': 3984}
# {'nome': 'Saveiro SPORTLINE 1.8 Mi Total Flex 8V', 'codigo': 3807}
# {'nome': 'Saveiro Startline 1.6 T.Flex 8V', 'codigo': 6802}
# {'nome': 'Saveiro Super Surf  1.8 Mi 8V 99cv', 'codigo': 2565}
# {'nome': 'Saveiro Super Surf 1.6 Mi Total Flex 8V', 'codigo': 2566}
# {'nome': 'Saveiro Super Surf 1.8 Mi Total Flex 8V', 'codigo': 2567}
# {'nome': 'Saveiro SURF 1.6 Mi Total Flex 2p', 'codigo': 4523}
# {'nome': 'Saveiro SURF 1.8 Mi Total Flex 2p', 'codigo': 4524}
# {'nome': 'Saveiro TITAN  1.6 Mi Total Flex 2p', 'codigo': 4451}
# {'nome': 'Saveiro Trendline 1.6 T.Flex 8V', 'codigo': 6799}
# {'nome': 'Saveiro Trendline 1.6 T.Flex 8V CD', 'codigo': 6943}
# {'nome': 'Saveiro Trendline 1.6 T.Flex 8V CE', 'codigo': 6800}
# {'nome': 'Saveiro Trendline 1.6 Total Flex 16V', 'codigo': 9872}
# {'nome': 'Saveiro TROOPER 1.6 Mi Total Flex 8V', 'codigo': 5010}
# {'nome': 'Saveiro TROOPER 1.6 Mi Total Flex 8V CE', 'codigo': 5011}
# {'nome': 'Saveiro TSi 2.0 Mi', 'codigo': 2568}
# {'nome': 'SpaceCross 1.6 Mi Total Flex 16V', 'codigo': 7235}
# {'nome': 'SpaceCross 1.6 Mi Total Flex 8V', 'codigo': 5655}
# {'nome': 'SpaceCross I MOTION 1.6 Mi T. Flex 16V', 'codigo': 7236}
# {'nome': 'SpaceCross I MOTION 1.6 Mi Total Flex 8V', 'codigo': 5656}
# {'nome': 'SPACEFOX  SPORTLINE/HIGHLINE 1.6 T.Flex', 'codigo': 4729}
# {'nome': 'SPACEFOX  TREND I MOTION 1.6 T. Flex 8V', 'codigo': 5314}
# {'nome': 'SPACEFOX 1.6 Trendline I MOT. T.Flex 8V', 'codigo': 7321}
# {'nome': 'SPACEFOX 1.6 Trendline Total Flex 8v 5p', 'codigo': 7322}
# {'nome': 'SPACEFOX 1.6/ 1.6 Trend Total Flex 8V 5p', 'codigo': 4007}
# {'nome': 'SPACEFOX COMF. I MOTION 1.6 Flex 8V 5p', 'codigo': 7217}
# {'nome': 'SPACEFOX COMFORTLINE 1.6 Mi T.Flex 8V 5p', 'codigo': 4008}
# {'nome': 'SPACEFOX HIGHLINE 1.6 T.Flex 16V', 'codigo': 7237}
# {'nome': 'SPACEFOX HIGHLINE I MOT. 1.6 T.Flex 16V', 'codigo': 7238}
# {'nome': 'SPACEFOX Route 1.6 Mi T.Flex 5p', 'codigo': 4836}
# {'nome': 'SPACEFOX SPORTLINE/HIGHLINE I MOTION 1.6', 'codigo': 5315}
# {'nome': 'TAOS Comfortline 1.4 250 TSI Flex Aut.', 'codigo': 9529}
# {'nome': 'TAOS Highline 1.4 250 TSI Flex Aut.', 'codigo': 9530}
# {'nome': 'TAOS Launching Ed. 1.4 250 TSI Flex Aut.', 'codigo': 9531}
# {'nome': 'T-Cross 1.0 TSI Flex 12V 5p Mec.', 'codigo': 8642}
# {'nome': 'T-Cross 200 TSI 1.0  Flex 12V 5p Aut.', 'codigo': 10373}
# {'nome': 'T-Cross Comfor. 200 TSI 1.0 Flex 5p Aut.', 'codigo': 10374}
# {'nome': 'T-Cross Hig. 250 TSI 1.4 Flex 16V 5p Aut', 'codigo': 10375}
# {'nome': 'T-Cross Sense 200 TSI 1.0 Flex 5p Aut.', 'codigo': 10376}
# {'nome': 'TIGUAN 1.4 TSI 16V 150cv 5p', 'codigo': 7860}
# {'nome': 'TIGUAN 2.0 TSI 16V 200cv Tiptronic 5p', 'codigo': 4931}
# {'nome': 'TIGUAN Allspac 250 TSI 1.4 Flex', 'codigo': 8300}
# {'nome': 'TIGUAN Allspac Comf 250 TSI 1.4 Flex', 'codigo': 8301}
# {'nome': 'TIGUAN Allspac R-Line 350 TSI 2.0 4x4', 'codigo': 8302}
# {'nome': 'TOUAREG 3.2 24V V6 Tiptronic 5p', 'codigo': 3835}
# {'nome': 'TOUAREG 3.6 24V V6 280cv Tiptronic 5p', 'codigo': 4442}
# {'nome': 'TOUAREG 4.2 32V V8  Tiptronic 5p', 'codigo': 2569}
# {'nome': 'TOUAREG R-Line 4.2 V8 360cv Tiptronic 5p', 'codigo': 7218}
# {'nome': 'up! 1.0 Total Flex 12V 5p', 'codigo': 8702}
# {'nome': 'up! black/white/red 1.0 T. Flex 12V 5p', 'codigo': 6715}
# {'nome': 'up! black/white/red 1.0 TSI TFlex 12V 5p', 'codigo': 7323}
# {'nome': 'up! black/white/red I MOTION 1.0 Flex 5p', 'codigo': 6803}
# {'nome': 'up! Connect 1.0 TSI Total Flex 12V 5p', 'codigo': 8703}
# {'nome': 'up! cross 1.0 T. Flex 12V 5p', 'codigo': 7047}
# {'nome': 'up! cross 1.0 TSI Total Flex 12V 5p', 'codigo': 7324}
# {'nome': 'up! cross I MOTION 1.0 T.Flex 12V 5p', 'codigo': 7048}
# {'nome': 'up! high 1.0 Total Flex 12V 5p', 'codigo': 6716}
# {'nome': 'up! high 1.0 TSI Total Flex 12V 5p', 'codigo': 7325}
# {'nome': 'up! high I MOTION 1.0 T. Flex 12V 5p', 'codigo': 6804}
# {'nome': 'up! move 1.0 T. Flex 12V 3p', 'codigo': 6805}
# {'nome': 'up! move 1.0 Total Flex 12V 5p', 'codigo': 6717}
# {'nome': 'up! move 1.0 TSI Total Flex 12V 5p', 'codigo': 7326}
# {'nome': 'up! move I MOTION 1.0 T. Flex 12V 3p', 'codigo': 6806}
# {'nome': 'up! move I MOTION 1.0 T. Flex 12V 5p', 'codigo': 6846}
# {'nome': 'up! Pepper 1.0 TSI T.Flex 12V 5p', 'codigo': 8028}
# {'nome': 'up! Run 1.0 Total Flex 12V 5p', 'codigo': 7639}
# {'nome': 'up! Run I MOTION 1.0 Total Flex 12V 5p', 'codigo': 7640}
# {'nome': 'up! SPEED 1.0 TSI T. Flex 12V 5p', 'codigo': 7327}
# {'nome': 'up! take 1.0 T. Flex 12V 3p', 'codigo': 6807}
# {'nome': 'up! take 1.0 Total Flex 12V 5p', 'codigo': 6718}
# {'nome': 'up! track 1.0 Total Flex 12V 5p', 'codigo': 7818}
# {'nome': 'up! Xtreme 1.0 TSI Total Flex 12V 5p', 'codigo': 8704}
# {'nome': 'Van 1.6 Mi (furgão)', 'codigo': 2570}
# {'nome': 'VIRTUS 1.6 MSI Flex 16V 4p Aut.', 'codigo': 8427}
# {'nome': 'VIRTUS 1.6 MSI Flex 16V 5p Mec.', 'codigo': 8184}
# {'nome': 'VIRTUS Comfort. 200 TSI 1.0 Flex 12V Aut', 'codigo': 8185}
# {'nome': 'VIRTUS GTS 1.4 TSI 16V Flex 4p', 'codigo': 8997}
# {'nome': 'VIRTUS Highline 200 TSI 1.0 Flex 12V Aut', 'codigo': 8186}
# {'nome': 'VIRTUS Sense 1.6 Flex 16V 5p Aut. ', 'codigo': 9599}
# {'nome': 'VOYAGE  Trendline 1.0 T.Flex 8V 4p', 'codigo': 6808}
# {'nome': 'VOYAGE 1.0 Flex 12V 4p', 'codigo': 8325}
# {'nome': 'VOYAGE 1.0/1.0 City Mi Total Flex 8V 4p', 'codigo': 4752}
# {'nome': 'VOYAGE 1.6 MSI Flex 16V 4p Aut.', 'codigo': 8464}
# {'nome': 'VOYAGE 1.6 MSI Flex 8V 4p', 'codigo': 8326}
# {'nome': 'VOYAGE 1.6/1.6 City  Mi Total Flex 8V 4p', 'codigo': 4753}
# {'nome': 'VOYAGE C/CL/Fox 1.6', 'codigo': 2571}
# {'nome': 'VOYAGE CL 1.8', 'codigo': 2572}
# {'nome': 'VOYAGE COMF/Highli. 1.6 T.Flex 8V 4p', 'codigo': 4754}
# {'nome': 'VOYAGE Comfortline  1.0 T.Flex 8V 4p', 'codigo': 6810}
# {'nome': 'VOYAGE Comfortline 1.0 T.Flex 12V 4p', 'codigo': 7523}
# {'nome': 'VOYAGE Evidence 1.6 Total Flex 8V 4p', 'codigo': 6811}
# {'nome': 'VOYAGE GL 1.8 4p (Argentino)', 'codigo': 2573}
# {'nome': 'VOYAGE GL/ Special 1.6/ 1.8', 'codigo': 2574}
# {'nome': 'VOYAGE I MOTION  Trendline 1.6 T.Flex 8V', 'codigo': 6812}
# {'nome': 'VOYAGE I MOTION 1.6 Mi Total Flex 8V', 'codigo': 5116}
# {'nome': 'VOYAGE I MOTION COMF/Hghli.1.6 T.Flex 8V', 'codigo': 5117}
# {'nome': 'VOYAGE I MOTION Evidence 1.6 T.Flex 8V', 'codigo': 6813}
# {'nome': 'VOYAGE I MOTION TREND 1.6 Mi T. Flex 8V', 'codigo': 5118}
# {'nome': 'VOYAGE L/LS/Plus/GLS/S/Sport/Super L.Ang', 'codigo': 2575}
# {'nome': 'VOYAGE SELEÇÃO 1.0 Mi Total Flex 8V 4p', 'codigo': 6671}
# {'nome': 'VOYAGE SELEÇÃO 1.6 I MOTION T.Flex 8V 4p', 'codigo': 6672}
# {'nome': 'VOYAGE SELEÇÃO 1.6 Total Flex 8V 4p', 'codigo': 6673}
# {'nome': 'VOYAGE TREND 1.6 Mi Total Flex 8V 4p', 'codigo': 4755}
# {'nome': 'VOYAGE Trendline 1.0 T.Flex 12V 4p', 'codigo': 7524}
# {'nome': 'VOYAGE Trendline 1.6 T.Flex 8V 4p', 'codigo': 6809}
